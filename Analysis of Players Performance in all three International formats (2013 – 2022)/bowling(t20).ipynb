# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_t20=pd.read_csv(r'C:\Users\vodna\OneDrive\Desktop\p\bowling(T20).csv')
df_t20
# Out:
#                     player  matches  inn  overs  maiden   runs  wkts bb_inn  \
# 0        JW Dernbach (ENG)        4    3   12.0     0.0   88.0   7.0   3/23
# 1    Mohammad Hafeez (PAK)        4    4   12.0     1.0   55.0   7.0   3/30
# 2     Zulfiqar Babar (PAK)        3    3   12.0     1.0   81.0   7.0   3/23
# 3    Shakib Al Hasan (BAN)        2    2    8.0     0.0   41.0   6.0   4/21
# 4        SO Ngoche (KENYA)        3    3   11.0     0.0   87.0   5.0   4/34
# ..                     ...      ...  ...    ...     ...    ...   ...    ...
# 495  Ngawang Thinley (BHU)        7    7   18.3     1.0  121.0  13.0   4/13
# 496           L Ngidi (SA)        7    7   20.1     0.0  139.0  13.0   5/39
# 497         HV Patel (IND)       12   11   35.1     0.0  334.0  13.0   4/25
# 498      Rashid Khan (AFG)       13   13   49.0     0.0  320.0  13.0   3/22
# 499        M Sarenac (SRB)        9    9   23.0     0.0  183.0  13.0   3/18
#
#        avg  econ    sr  _4w  _5w  season
# ...

# %%
df_t20.isna().sum()
# Out:
# player      0
# matches     0
# inn         0
# overs      17
# maiden     17
# runs       17
# wkts       17
# bb_inn     25
# avg        25
# econ       25
# sr         25
# _4w        25
# _5w        25
# season     25
# dtype: int64

# %%
df_t20=df_t20.dropna()

# %%
df_t20.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 475 entries, 0 to 499
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   player   475 non-null    object
#  1   matches  475 non-null    int64
#  2   inn      475 non-null    int64
#  3   overs    475 non-null    float64
#  4   maiden   475 non-null    float64
#  5   runs     475 non-null    float64
#  6   wkts     475 non-null    float64
#  7   bb_inn   475 non-null    object
#  8   avg      475 non-null    float64
#  9   econ     475 non-null    float64
#  10  sr       475 non-null    float64
#  11  _4w      475 non-null    float64
#  12  _5w      475 non-null    float64
#  13  season   475 non-null    float64
# dtypes: float64(10), int64(2), object(2)
# memory usage: 55.7+ KB

# %%
df_t20=df_t20.rename(columns={'inn':'innings',
                       'wkts':'wickets',
                       'bb_inn':'best_bowling_innings',
                       'avg':'average',
                       'econ':'economy',
                       'sr':'strike rate',
                       "_5w": "5wicket_haul",
                       "_4w": "4wicket_haul",
                       'runs':'runs conceded',
                       'season':'year'})
df_t20
# Out:
#                     player  matches  innings  overs  maiden  runs conceded  \
# 0        JW Dernbach (ENG)        4        3   12.0     0.0           88.0
# 1    Mohammad Hafeez (PAK)        4        4   12.0     1.0           55.0
# 2     Zulfiqar Babar (PAK)        3        3   12.0     1.0           81.0
# 3    Shakib Al Hasan (BAN)        2        2    8.0     0.0           41.0
# 4        SO Ngoche (KENYA)        3        3   11.0     0.0           87.0
# ..                     ...      ...      ...    ...     ...            ...
# 495  Ngawang Thinley (BHU)        7        7   18.3     1.0          121.0
# 496           L Ngidi (SA)        7        7   20.1     0.0          139.0
# 497         HV Patel (IND)       12       11   35.1     0.0          334.0
# 498      Rashid Khan (AFG)       13       13   49.0     0.0          320.0
# 499        M Sarenac (SRB)        9        9   23.0     0.0          183.0
#
#      wickets best_bowling_innings  average  economy  strike rate  \
# ...

# %%
df_t20.columns
# Out:
# Index(['player', 'matches', 'innings', 'overs', 'maiden', 'runs conceded',
#        'wickets', 'best_bowling_innings', 'average', 'economy', 'strike rate',
#        '4wicket_haul', '5wicket_haul', 'year'],
#       dtype='object')

# %%
column=['maiden', 'runs conceded', 'wickets','4wicket_haul', '5wicket_haul', 'year']
for i in column:
    df_t20[i]=df_t20[i].astype('int')

# %%
df_t20[['player','country']]=df_t20['player'].str.split('(',n=1,expand=True)
df_t20
# Out:
#                player  matches  innings  overs  maiden  runs conceded  \
# 0        JW Dernbach         4        3   12.0       0             88
# 1    Mohammad Hafeez         4        4   12.0       1             55
# 2     Zulfiqar Babar         3        3   12.0       1             81
# 3    Shakib Al Hasan         2        2    8.0       0             41
# 4          SO Ngoche         3        3   11.0       0             87
# ..                ...      ...      ...    ...     ...            ...
# 495  Ngawang Thinley         7        7   18.3       1            121
# 496          L Ngidi         7        7   20.1       0            139
# 497         HV Patel        12       11   35.1       0            334
# 498      Rashid Khan        13       13   49.0       0            320
# 499        M Sarenac         9        9   23.0       0            183
#
#      wickets best_bowling_innings  average  economy  strike rate  \
# ...

# %%
df_t20['country']=df_t20['country'].str.replace(')','')

# %%
df_t20["balls_bowled"] = df_t20["overs"].astype(str).str.split(".").apply(lambda x: int(x[0]) * 6 + int(x[1]) if len(x) > 1 else int(x[0]) * 6)
df_t20
# Out:
#                player  matches  innings  overs  maiden  runs conceded  \
# 0        JW Dernbach         4        3   12.0       0             88
# 1    Mohammad Hafeez         4        4   12.0       1             55
# 2     Zulfiqar Babar         3        3   12.0       1             81
# 3    Shakib Al Hasan         2        2    8.0       0             41
# 4          SO Ngoche         3        3   11.0       0             87
# ..                ...      ...      ...    ...     ...            ...
# 495  Ngawang Thinley         7        7   18.3       1            121
# 496          L Ngidi         7        7   20.1       0            139
# 497         HV Patel        12       11   35.1       0            334
# 498      Rashid Khan        13       13   49.0       0            320
# 499        M Sarenac         9        9   23.0       0            183
#
#      wickets best_bowling_innings  average  economy  strike rate  \
# ...

# %%
df_t20=df_t20[['player', 'country', 'matches', 'innings', 'overs','balls_bowled', 'maiden', 'runs conceded', 'wickets',
       'best_bowling_innings', 'average', 'economy', 'strike rate',
       '4wicket_haul', '5wicket_haul', 'year']]

df_t20
# Out:
#                player country  matches  innings  overs  balls_bowled  maiden  \
# 0        JW Dernbach      ENG        4        3   12.0            72       0
# 1    Mohammad Hafeez      PAK        4        4   12.0            72       1
# 2     Zulfiqar Babar      PAK        3        3   12.0            72       1
# 3    Shakib Al Hasan      BAN        2        2    8.0            48       0
# 4          SO Ngoche    KENYA        3        3   11.0            66       0
# ..                ...     ...      ...      ...    ...           ...     ...
# 495  Ngawang Thinley      BHU        7        7   18.3           111       1
# 496          L Ngidi       SA        7        7   20.1           121       0
# 497         HV Patel      IND       12       11   35.1           211       0
# 498      Rashid Khan      AFG       13       13   49.0           294       0
# 499        M Sarenac      SRB        9        9   23.0           138       0
#
# ...

# %%
df_t20['weight score']=(0.4*df_t20['wickets'])-(0.3*df_t20['average'])-(0.2*df_t20['economy'])-(0.1*df_t20['strike rate'])
df_t20
# Out:
# C:\Users\vodna\AppData\Local\Temp\ipykernel_16680\2754180628.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_t20['weight score']=(0.4*df_t20['wickets'])-(0.3*df_t20['average'])-(0.2*df_t20['economy'])-(0.1*df_t20['strike rate'])
#                player country  matches  innings  overs  balls_bowled  maiden  \
# 0        JW Dernbach      ENG        4        3   12.0            72       0
# 1    Mohammad Hafeez      PAK        4        4   12.0            72       1
# 2     Zulfiqar Babar      PAK        3        3   12.0            72       1
# 3    Shakib Al Hasan      BAN        2        2    8.0            48       0
# 4          SO Ngoche    KENYA        3        3   11.0            66       0
# ...

# %%
fig,ax=plt.subplots(2,2,figsize=(15, 7))
plt.suptitle("Univariate Analysis of ODI Bowling Performance", fontsize=16)

plt.subplot(2, 2, 1)
sns.histplot(df_t20['average'],bins=10,ax=ax[0,0],kde=True,color='darkblue')
plt.title('Distribution of Bowling Average')
plt.xlabel('Average')
plt.ylabel('Values')

plt.subplot(2, 2, 2)
sns.boxplot(x=df_t20['strike rate'],ax=ax[0,1],color='lightblue')
plt.title('Boxplot of Strike Rate')
plt.xlabel('Strike Rate')

plt.subplot(2, 2, 3)
sns.histplot(df_t20['runs conceded'],bins=10,ax=ax[1,0],kde=True,color='darkgreen')
plt.title('Distribution of Runs Conceded')
plt.xlabel('Runs Conceded')
plt.ylabel('Values')

plt.subplot(2, 2, 4)
sns.boxplot(x=df_t20['economy'],ax=ax[1,1],color='lightblue')
plt.title('Boxplot of Economy Rate')
plt.xlabel('Economy Rate')

plt.tight_layout()
plt.show()

# %%
top_wicket_taker_player=df_t20.groupby('player')[['wickets']].max().reset_index().sort_values(by='wickets',ascending=False).head(10)

plt.figure(figsize=(12,4))

sns.barplot(y=top_wicket_taker_player['player'],x=top_wicket_taker_player['wickets'],color='darkblue')
plt.title("Top 10 wicket takers in ODI")
plt.show()
top_wicket_taker_player
# Out:
#                  player  wickets
# 46             B Kumar        27
# 182          LM Jongwe        26
# 346       Waseem Abbas        24
# 4           A Nathwani        23
# 321           T Shamsi        22
# 349       Zaker Taqawi        20
# 92          Ehsan Khan        20
# 138          JB Little        20
# 25   Abdullah Akbarjan        20
# 305       Shahil Momin        19

# %%
top_wicket_by_country=df_t20.groupby('country')[['wickets']].max().reset_index().sort_values(by='wickets',ascending=False).head(10)
plt.figure(figsize=(10,4))

sns.barplot(data=top_wicket_by_country,x='wickets',y='country',color='darkblue')
plt.title('Top 10 wickets by country wise')
plt.show()
top_wicket_by_country
# Out:
#    country  wickets
# 23     IND       27
# 54     ZIM       26
# 32     MLT       24
# 4      Aut       23
# 43      SA       22
# 48     SWE       20
# 25     IRE       20
# 21     HKG       20
# 9      BUL       19
# 5      BAN       18

# %%
avg_eco_sr_trend=df_t20.groupby('year')[['average','economy','strike rate']].mean().reset_index()

plt.figure(figsize=(10,4))
sns.lineplot(data=avg_eco_sr_trend,x='year',y='average',marker='o',label='average',color='darkblue')
sns.lineplot(data=avg_eco_sr_trend,x='year',y='economy',marker='s',label='economy',color='red')
sns.lineplot(data=avg_eco_sr_trend,x='year',y='strike rate',marker='^',label='strike rate',color='darkgreen')

plt.grid(True)
plt.xlabel('year')
plt.ylabel('values')
plt.title('Yearly Trend of Bowling Average,Economy and Strike Rate')
plt.legend()
plt.show()

avg_eco_sr_trend
# Out:
#    year    average   economy  strike rate
# 0  2013  22.299000  7.187800    18.448000
# 1  2014  27.451429  8.047500    20.225000
# 2  2015  19.660000  7.131800    16.440000
# 3  2016  27.730851  7.639362    20.323404
# 4  2017  28.639600  7.471400    22.822000
# 5  2018  23.307600  8.076400    17.426000
# 6  2019  13.902600  6.514600    12.670000
# 7  2020  26.855000  7.974800    20.630000
# 8  2021  16.239400  6.578600    14.780000
# 9  2022  17.305400  6.894800    14.710000

# %%
best_fig=df_t20.groupby('player')[['best_bowling_innings']].max().reset_index().sort_values(by='best_bowling_innings',ascending=False).head(10)

best_fig
# Out:
#              player best_bowling_innings
# 240       OC McCoy                  6/17
# 60       C Viljoen                   5/9
# 40      Aqib Iqbal                   5/5
# 46         B Kumar                   5/4
# 174        L Ngidi                  5/39
# 346   Waseem Abbas                  5/37
# 172  Kuldeep Yadav                  5/24
# 8         AC Evans                  5/24
# 224       N Nipiko                  5/19
# 73     CW Perchard                  5/17

# %%
top_wicket_year=df_t20.groupby('year')['wickets'].max().reset_index()

plt.figure(figsize=(10,4))
top_player = top_wicket_year.iloc[9]["year"]
colors = ["darkgreen" if player == top_player else "darkblue" for player in top_wicket_year["year"]]
sns.barplot(data=top_wicket_year,x='year',y='wickets',palette=colors)
plt.title('Highest Wickets By Year')
plt.show()

top_wicket_year
# Out:
# C:\Users\vodna\AppData\Local\Temp\ipykernel_16680\676117735.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=top_wicket_year,x='year',y='wickets',palette=colors)
#    year  wickets
# 0  2013        7
# 1  2014        4
# 2  2015       16
# 3  2016        9
# 4  2017       17
# 5  2018       17
# 6  2019       15
# 7  2020        8
# 8  2021       26
# 9  2022       27

# %%
top_maiden=df_t20.groupby('player')['maiden'].max().reset_index().sort_values(by='maiden',ascending=False).head(10)

plt.figure(figsize=(12,4))
sns.barplot(data=top_maiden,x='player',y='maiden',color='darkblue')
plt.title('Top 10 Maiden overs bowled')
plt.show()
top_maiden
# Out:
#                player  maiden
# 255        R Ngarava        4
# 46           B Kumar        4
# 104    Ghulam Ahmadi        3
# 58    Bilal Muhammad        3
# 40        Aqib Iqbal        3
# 146           JJ Huo        3
# 338  Virandeep Singh        3
# 235      Nasum Ahmed        3
# 135         J Miyagi        3
# 225          N Vanua        2

# %%
df_t20[['4wicket_haul','5wicket_haul']].sum()

plt.pie(x=[df_t20['4wicket_haul'].sum(),df_t20['5wicket_haul'].sum()],labels=('4 wicket hauls','5 wicket hauls'),colors=['darkblue', 'darkgreen'], autopct='%1.1f%%', explode=(0.1,0), shadow=True)
plt.title('contribution of 4 & 5 wicket hauls in ODI')
# Out:
# Text(0.5, 1.0, 'contribution of 4 & 5 wicket hauls in ODI')

# %%
top_4wickets=df_t20.groupby('player')['4wicket_haul'].max().reset_index().sort_values(by='4wicket_haul',ascending=False).head()

plt.figure(figsize=(8,5))
sns.barplot(data=top_4wickets,x='player',y='4wicket_haul',color='darkblue')
plt.title('Top 5 4wicket hauls')
plt.show()

top_4wickets
# Out:
#             player  4wicket_haul
# 305  Shahil Momin              2
# 46        B Kumar              2
# 240      OC McCoy              2
# 235   Nasum Ahmed              2
# 266   Rashid Khan              2

# %%
top_5wickets=df_t20.groupby('player')['5wicket_haul'].max().reset_index().sort_values(by='5wicket_haul',ascending=False).head()

plt.figure(figsize=(8,5))
sns.barplot(data=top_5wickets,x='player',y='5wicket_haul',color='darkblue')
plt.title('Top 5 5wicket hauls')
plt.show()

top_5wickets
# Out:
#             player  5wicket_haul
# 349  Zaker Taqawi              2
# 175      LA Burns              1
# 77         D Ravu              1
# 46        B Kumar              1
# 298  Sahel Zadran              1

# %%
a=df_t20.groupby(['year','player','average','economy', 'strike rate'])['wickets'].max().reset_index()
b=a.loc[a.groupby('year')['wickets'].idxmax()]


fig, ax1 = plt.subplots(figsize=(15, 5))

sns.barplot(x=b['player'], y=b['wickets'], ax=ax1, color='darkblue', label='Wickets',errorbar=None)
ax1.set_ylabel("Wickets")
ax1.set_xlabel("Player")
plt.xticks(rotation=45)

ax2 = ax1.twinx()

sns.lineplot(x=b['player'], y=b['average'], marker='o', ax=ax2, label='Average', color='red',errorbar=None)
sns.lineplot(x=b['player'], y=b['economy'], marker='o', ax=ax2, label='Economy', color='green',errorbar=None)
sns.lineplot(x=b['player'], y=b['strike rate'], marker='o', ax=ax2, label='Strike Rate', color='purple',errorbar=None)

ax2.set_ylabel("Average,Economy and Strike rate", color='black')
ax2.set_xlabel("Player")
plt.xticks(rotation=45)

fig.suptitle("Year wise Top Bowling Performance")

ax1.legend(loc='upper left')
ax2.legend(loc='upper right')






plt.show()

b
# Out:
#      year          player  average  economy  strike rate  wickets
# 17   2013    JW Dernbach     12.57     7.33         10.2        7
# 76   2014       TA Boult     12.50     6.25         12.0        4
# 84   2015    Ahsan Malik     10.68     6.93          9.2       16
# 149  2016      JJ Bumrah     14.55     6.55         13.3        9
# 197  2017   KOK Williams     12.88     6.95         11.1       17
# 263  2018    Rashid Khan      8.76     6.77          7.7       17
# 299  2019  Iqbal Hussain     13.66     8.31          9.8       15
# 330  2020      AU Rashid     18.37     7.73         14.2        8
# 399  2021      LM Jongwe     15.38     7.89         11.6       26
# 432  2022        B Kumar     16.92     7.14         14.2       27

# %%
best_10=df_t20.nlargest(10,'weight score')

plt.figure(figsize=(13,5))
sns.barplot(data=best_10,x='weight score',y='player',color='darkblue')
plt.title('Best 10 Players')
plt.show()

best_10
# Out:
#                  player  country  matches  innings  overs  balls_bowled  \
# 455       Zaker Taqawi       SWE        9        9   28.3           171
# 451         A Nathwani       Aut       13       13   47.0           282
# 401       Waseem Abbas       MLT       13       13   45.3           273
# 400          LM Jongwe       ZIM       14       14   50.4           304
# 450            B Kumar       IND       20       19   64.0           384
# 471      Syazrul Idrus       MAS        6        6   18.4           112
# 464         Vraj Patel     KENYA        8        8   31.0           186
# 402           T Shamsi        SA       14       14   53.0           318
# 250        Rashid Khan   AFG/ICC        6        6   22.0           132
# 404  Mustafizur Rahman       BAN       10       10   35.2           212
#
#      maiden  runs conceded  wickets best_bowling_innings  average  economy  \
# 455       2            166       20                 5/17     8.30     5.82
# ...

# %%
final=best_10[['player','country','weight score']]

# %%
final=final.rename(columns={'country':'Team'})

# %%
final.to_csv('top_5_bow_t20.csv')
