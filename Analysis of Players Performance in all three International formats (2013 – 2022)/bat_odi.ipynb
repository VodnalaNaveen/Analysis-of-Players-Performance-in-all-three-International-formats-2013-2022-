# %%
import pandas as pd

# %%
df = pd.read_csv(r'E:\inno\Cricket EDA\batting(odi).csv')
df
# Out:
#                     player  matches  inn   no   runs    hs    avg     bf  \
# 0       KC Sangakkara (SL)       14   13  3.0  772.0   169  77.20  842.0
# 1           S Dhawan (IND)       14   14  1.0  707.0   116  54.38  756.0
# 2      Misbah-ul-Haq (PAK)       14   14  4.0  693.0   96*  69.30  964.0
# 3            V Kohli (IND)       15   13  3.0  521.0   115  52.10  564.0
# 4    Mohammad Hafeez (PAK)       14   14  3.0  517.0  136*  47.00  595.0
# ..                     ...      ...  ...  ...    ...   ...    ...    ...
# 487      Tamim Iqbal (BAN)        6    6  1.0  248.0    62  49.60  302.0
# 488     KH Prajapati (OMA)        8    8  0.0  244.0   103  30.50  323.0
# 489        TWM Latham (NZ)        9    9  0.0  242.0    69  26.88  296.0
# 490        CJA Amini (PNG)        8    8  0.0  225.0    60  28.12  381.0
# 491        HT Tector (IRE)        3    3  0.0  225.0   113  75.00  248.0
#
#         sr  _100  _50   _0   _4s   _6s  season
# ...

# %%
df[['Player', 'Team']] = df['player'].str.split('(', n=1, expand=True)
df
# Out:
#                     player  matches  inn   no   runs    hs    avg     bf  \
# 0       KC Sangakkara (SL)       14   13  3.0  772.0   169  77.20  842.0
# 1           S Dhawan (IND)       14   14  1.0  707.0   116  54.38  756.0
# 2      Misbah-ul-Haq (PAK)       14   14  4.0  693.0   96*  69.30  964.0
# 3            V Kohli (IND)       15   13  3.0  521.0   115  52.10  564.0
# 4    Mohammad Hafeez (PAK)       14   14  3.0  517.0  136*  47.00  595.0
# ..                     ...      ...  ...  ...    ...   ...    ...    ...
# 487      Tamim Iqbal (BAN)        6    6  1.0  248.0    62  49.60  302.0
# 488     KH Prajapati (OMA)        8    8  0.0  244.0   103  30.50  323.0
# 489        TWM Latham (NZ)        9    9  0.0  242.0    69  26.88  296.0
# 490        CJA Amini (PNG)        8    8  0.0  225.0    60  28.12  381.0
# 491        HT Tector (IRE)        3    3  0.0  225.0   113  75.00  248.0
#
#         sr  _100  _50   _0   _4s   _6s  season            Player  Team
# ...

# %%
df['Team'] = df['Team'].str.replace(')','')
df
# Out:
#                     player  matches  inn   no   runs    hs    avg     bf  \
# 0       KC Sangakkara (SL)       14   13  3.0  772.0   169  77.20  842.0
# 1           S Dhawan (IND)       14   14  1.0  707.0   116  54.38  756.0
# 2      Misbah-ul-Haq (PAK)       14   14  4.0  693.0   96*  69.30  964.0
# 3            V Kohli (IND)       15   13  3.0  521.0   115  52.10  564.0
# 4    Mohammad Hafeez (PAK)       14   14  3.0  517.0  136*  47.00  595.0
# ..                     ...      ...  ...  ...    ...   ...    ...    ...
# 487      Tamim Iqbal (BAN)        6    6  1.0  248.0    62  49.60  302.0
# 488     KH Prajapati (OMA)        8    8  0.0  244.0   103  30.50  323.0
# 489        TWM Latham (NZ)        9    9  0.0  242.0    69  26.88  296.0
# 490        CJA Amini (PNG)        8    8  0.0  225.0    60  28.12  381.0
# 491        HT Tector (IRE)        3    3  0.0  225.0   113  75.00  248.0
#
#         sr  _100  _50   _0   _4s   _6s  season            Player Team
# ...

# %%
df = df.reindex(columns = ['Player', 'Team', 'player', 'matches', 'inn', 'no', 'runs', 'hs', 'avg', 'bf', 'sr', '_100', '_50', '_0', '_4s', '_6s', 'season'] )
df
# Out:
#                Player Team                 player  matches  inn   no   runs  \
# 0      KC Sangakkara    SL     KC Sangakkara (SL)       14   13  3.0  772.0
# 1           S Dhawan   IND         S Dhawan (IND)       14   14  1.0  707.0
# 2      Misbah-ul-Haq   PAK    Misbah-ul-Haq (PAK)       14   14  4.0  693.0
# 3            V Kohli   IND          V Kohli (IND)       15   13  3.0  521.0
# 4    Mohammad Hafeez   PAK  Mohammad Hafeez (PAK)       14   14  3.0  517.0
# ..                ...  ...                    ...      ...  ...  ...    ...
# 487      Tamim Iqbal   BAN      Tamim Iqbal (BAN)        6    6  1.0  248.0
# 488     KH Prajapati   OMA     KH Prajapati (OMA)        8    8  0.0  244.0
# 489       TWM Latham    NZ        TWM Latham (NZ)        9    9  0.0  242.0
# 490        CJA Amini   PNG        CJA Amini (PNG)        8    8  0.0  225.0
# 491        HT Tector   IRE        HT Tector (IRE)        3    3  0.0  225.0
#
# ...

# %%
df = df.drop(columns= 'player')
df
# Out:
#                Player Team  matches  inn   no   runs    hs    avg     bf  \
# 0      KC Sangakkara    SL       14   13  3.0  772.0   169  77.20  842.0
# 1           S Dhawan   IND       14   14  1.0  707.0   116  54.38  756.0
# 2      Misbah-ul-Haq   PAK       14   14  4.0  693.0   96*  69.30  964.0
# 3            V Kohli   IND       15   13  3.0  521.0   115  52.10  564.0
# 4    Mohammad Hafeez   PAK       14   14  3.0  517.0  136*  47.00  595.0
# ..                ...  ...      ...  ...  ...    ...   ...    ...    ...
# 487      Tamim Iqbal   BAN        6    6  1.0  248.0    62  49.60  302.0
# 488     KH Prajapati   OMA        8    8  0.0  244.0   103  30.50  323.0
# 489       TWM Latham    NZ        9    9  0.0  242.0    69  26.88  296.0
# 490        CJA Amini   PNG        8    8  0.0  225.0    60  28.12  381.0
# 491        HT Tector   IRE        3    3  0.0  225.0   113  75.00  248.0
#
#         sr  _100  _50   _0   _4s   _6s  season
# ...

# %%
df = df.rename(columns={'inn':'innings',
                   'no':'Not_out',
                   'hs':'Highest_score',
                   'bf':'Balls_faced',
                   'avg':'average',
                   'sr':'Strike_rate',
                   '_100':'100s',
                   '_50':'50s',
                   '_0':'Duck_out',
                   '_4s':'4s',
                   '_6s':'6s',
                   'season':'Year'})

df
# Out:
#                Player Team  matches  innings  Not_out   runs Highest_score  \
# 0      KC Sangakkara    SL       14       13      3.0  772.0           169
# 1           S Dhawan   IND       14       14      1.0  707.0           116
# 2      Misbah-ul-Haq   PAK       14       14      4.0  693.0           96*
# 3            V Kohli   IND       15       13      3.0  521.0           115
# 4    Mohammad Hafeez   PAK       14       14      3.0  517.0          136*
# ..                ...  ...      ...      ...      ...    ...           ...
# 487      Tamim Iqbal   BAN        6        6      1.0  248.0            62
# 488     KH Prajapati   OMA        8        8      0.0  244.0           103
# 489       TWM Latham    NZ        9        9      0.0  242.0            69
# 490        CJA Amini   PNG        8        8      0.0  225.0            60
# 491        HT Tector   IRE        3        3      0.0  225.0           113
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 492 entries, 0 to 491
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Player         492 non-null    object
#  1   Team           492 non-null    object
#  2   matches        492 non-null    int64
#  3   innings        492 non-null    int64
#  4   Not_out        488 non-null    float64
#  5   runs           483 non-null    float64
#  6   Highest_score  484 non-null    object
#  7   average        482 non-null    object
#  8   Balls_faced    477 non-null    float64
#  9   Strike_rate    477 non-null    float64
#  10  100s           477 non-null    float64
#  11  50s            477 non-null    float64
#  12  Duck_out       477 non-null    float64
#  13  4s             477 non-null    float64
#  14  6s             477 non-null    float64
#  15  Year           477 non-null    float64
# dtypes: float64(10), int64(2), object(4)
# memory usage: 61.6+ KB

# %%
df.isna().sum()
# Out:
# Player            0
# Team              0
# matches           0
# innings           0
# Not_out           4
# runs              9
# Highest_score     8
# average          10
# Balls_faced      15
# Strike_rate      15
# 100s             15
# 50s              15
# Duck_out         15
# 4s               15
# 6s               15
# Year             15
# dtype: int64

# %%
col = ['Not_out','Balls_faced', '100s', '50s', 'Duck_out', '4s', '6s']
for i in col:
    df[i] = df[i].fillna(0)

# %%
df.isna().sum()
# Out:
# Player            0
# Team              0
# matches           0
# innings           0
# Not_out           0
# runs              9
# Highest_score     8
# average          10
# Balls_faced       0
# Strike_rate      15
# 100s              0
# 50s               0
# Duck_out          0
# 4s                0
# 6s                0
# Year             15
# dtype: int64

# %%
df = df.dropna(subset = ['runs'])

# %%
df.isna().sum()
# Out:
# Player           0
# Team             0
# matches          0
# innings          0
# Not_out          0
# runs             0
# Highest_score    0
# average          2
# Balls_faced      0
# Strike_rate      6
# 100s             0
# 50s              0
# Duck_out         0
# 4s               0
# 6s               0
# Year             6
# dtype: int64

# %%
df['Dismissals'] = df['innings'] - df['Not_out']
df['average'] = round(df['runs']/df['Dismissals'],2)
df['Strike_rate'] = round((df['runs']/df['Balls_faced'])*100,2)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_13220\1392224033.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Dismissals'] = df['innings'] - df['Not_out']
# C:\Users\DELL\AppData\Local\Temp\ipykernel_13220\1392224033.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['average'] = round(df['runs']/df['Dismissals'],2)
# C:\Users\DELL\AppData\Local\Temp\ipykernel_13220\1392224033.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df.isna().sum()
# Out:
# Player           0
# Team             0
# matches          0
# innings          0
# Not_out          0
# runs             0
# Highest_score    0
# average          0
# Balls_faced      0
# Strike_rate      0
# 100s             0
# 50s              0
# Duck_out         0
# 4s               0
# 6s               0
# Year             6
# Dismissals       0
# dtype: int64

# %%
df['Year'] = df['Year'].ffill()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_13220\708031714.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Year'] = df['Year'].ffill()

# %%
df.isna().sum()
# Out:
# Player           0
# Team             0
# matches          0
# innings          0
# Not_out          0
# runs             0
# Highest_score    0
# average          0
# Balls_faced      0
# Strike_rate      0
# 100s             0
# 50s              0
# Duck_out         0
# 4s               0
# 6s               0
# Year             0
# Dismissals       0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 483 entries, 0 to 491
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Player         483 non-null    object
#  1   Team           483 non-null    object
#  2   matches        483 non-null    int64
#  3   innings        483 non-null    int64
#  4   Not_out        483 non-null    float64
#  5   runs           483 non-null    float64
#  6   Highest_score  483 non-null    object
#  7   average        483 non-null    float64
#  8   Balls_faced    483 non-null    float64
#  9   Strike_rate    483 non-null    float64
#  10  100s           483 non-null    float64
#  11  50s            483 non-null    float64
#  12  Duck_out       483 non-null    float64
#  13  4s             483 non-null    float64
#  14  6s             483 non-null    float64
#  15  Year           483 non-null    float64
#  16  Dismissals     483 non-null    float64
# ...

# %%
df["Highest_score"] = df["Highest_score"].str.replace("*", "", regex=False).astype(int)
df["average"] = pd.to_numeric(df["average"], errors="coerce")
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_13220\1065879819.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Highest_score"] = df["Highest_score"].str.replace("*", "", regex=False).astype(int)
# C:\Users\DELL\AppData\Local\Temp\ipykernel_13220\1065879819.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["average"] = pd.to_numeric(df["average"], errors="coerce")

# %%
col = ['Not_out', 'runs', 'Balls_faced', '100s', '50s', 'Duck_out', '4s', '6s', 'Year', 'Dismissals']
for i in col:
    df[i] = df[i].astype('int')
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_13220\4286885906.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[i] = df[i].astype('int')
# C:\Users\DELL\AppData\Local\Temp\ipykernel_13220\4286885906.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[i] = df[i].astype('int')
# C:\Users\DELL\AppData\Local\Temp\ipykernel_13220\4286885906.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 483 entries, 0 to 491
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Player         483 non-null    object
#  1   Team           483 non-null    object
#  2   matches        483 non-null    int64
#  3   innings        483 non-null    int64
#  4   Not_out        483 non-null    int32
#  5   runs           483 non-null    int32
#  6   Highest_score  483 non-null    int32
#  7   average        483 non-null    float64
#  8   Balls_faced    483 non-null    int32
#  9   Strike_rate    483 non-null    float64
#  10  100s           483 non-null    int32
#  11  50s            483 non-null    int32
#  12  Duck_out       483 non-null    int32
#  13  4s             483 non-null    int32
#  14  6s             483 non-null    int32
#  15  Year           483 non-null    int32
#  16  Dismissals     483 non-null    int32
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df
# Out:
#                Player Team  matches  innings  Not_out  runs  Highest_score  \
# 0      KC Sangakkara    SL       14       13        3   772            169
# 1           S Dhawan   IND       14       14        1   707            116
# 2      Misbah-ul-Haq   PAK       14       14        4   693             96
# 3            V Kohli   IND       15       13        3   521            115
# 4    Mohammad Hafeez   PAK       14       14        3   517            136
# ..                ...  ...      ...      ...      ...   ...            ...
# 487      Tamim Iqbal   BAN        6        6        1   248             62
# 488     KH Prajapati   OMA        8        8        0   244            103
# 489       TWM Latham    NZ        9        9        0   242             69
# 490        CJA Amini   PNG        8        8        0   225             60
# 491        HT Tector   IRE        3        3        0   225            113
#
# ...

# %%
df["Boundary%"] = round(((df["4s"] * 4) + (df["6s"] * 6)) / df["runs"] * 100,2)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_13220\3669843693.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Boundary%"] = round(((df["4s"] * 4) + (df["6s"] * 6)) / df["runs"] * 100,2)

# %%
df
# Out:
#                Player Team  matches  innings  Not_out  runs  Highest_score  \
# 0      KC Sangakkara    SL       14       13        3   772            169
# 1           S Dhawan   IND       14       14        1   707            116
# 2      Misbah-ul-Haq   PAK       14       14        4   693             96
# 3            V Kohli   IND       15       13        3   521            115
# 4    Mohammad Hafeez   PAK       14       14        3   517            136
# ..                ...  ...      ...      ...      ...   ...            ...
# 487      Tamim Iqbal   BAN        6        6        1   248             62
# 488     KH Prajapati   OMA        8        8        0   244            103
# 489       TWM Latham    NZ        9        9        0   242             69
# 490        CJA Amini   PNG        8        8        0   225             60
# 491        HT Tector   IRE        3        3        0   225            113
#
# ...

# %%
df['Team'].nunique()
# Out:
# 20

# %%
df['Team'].unique()
# Out:
# array(['SL', 'IND', 'PAK', 'ENG', 'WI', 'NZ', 'SA', 'ZIM', 'IRE', 'AUS',
#        'SCOT', 'AFG', 'BAN', 'UAE', 'PNG', 'USA', 'OMA', 'NEP', 'NED',
#        'NAM'], dtype=object)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
top_10_scorers = df.nlargest(10, "runs")[["Player", "Team", "runs"]]

plt.figure(figsize=(5, 3))
sns.barplot(x="runs", y="Player", data=top_10_scorers, color= 'darkblue')
plt.xlabel("Total Runs")
plt.ylabel("Player")
plt.title("Top 10 Players by Runs in ODI")
plt.show()

top_10_scorers
# Out:
#                Player  Team  runs
# 200          V Kohli    IND   832
# 300          SD Hope     WI   779
# 0      KC Sangakkara     SL   772
# 301          JE Root    ENG   766
# 302       Babar Azam    PAK   751
# 303  Shakib Al Hasan    BAN   746
# 304      JM Bairstow    ENG   743
# 442       CS MacLeod   SCOT   736
# 305           JJ Roy    ENG   720
# 306  Mushfiqur Rahim    BAN   708

# %%
total_runs_by_team = df.groupby('Team')[['runs']].sum().reset_index()
total_runs_by_team
plt.figure(figsize=(7, 5))
sns.barplot(x=total_runs_by_team['runs'], y= total_runs_by_team['Team'], color= 'darkblue')
plt.xlabel("Total Runs")
plt.ylabel("Team")
plt.title("Total runs by Team in ODI")
plt.show()

# %%
top_scorers_by_year = df.loc[df.groupby('Year')['runs'].idxmax(), ['Year', 'Player', 'Team', 'runs']]
top_scorers_by_year = top_scorers_by_year.sort_values(by="Year")
top_scorers_by_year
# Out:
#      Year          Player  Team  runs
# 0    2013  KC Sangakkara     SL   772
# 50   2014   F du Plessis     SA   618
# 100  2015  KS Williamson     NZ   676
# 150  2016   LD Chandimal     SL   606
# 200  2017        V Kohli    IND   832
# 250  2018    Imam-ul-Haq    PAK   620
# 300  2019        SD Hope     WI   779
# 350  2020    SW Billings    ENG   315
# 392  2021       JN Malan     SA   493
# 442  2022     CS MacLeod   SCOT   736

# %%
yearly_stats = df.groupby(['Year'])[['average', 'Strike_rate']].mean().reset_index()

plt.figure(figsize=(8,3))
sns.lineplot(x="Year", y="average", data=yearly_stats, marker="o", label="Batting Average", color="darkblue")
sns.lineplot(x="Year", y="Strike_rate", data=yearly_stats, marker="s", label="Strike Rate", color="darkgreen")

plt.xlabel("Year")
plt.ylabel("Value")
plt.title("Yearly Trend of Batting Average and Strike Rate")
plt.legend()
plt.grid(True)
plt.show()

# %%
top_highest_scores = df.nlargest(10, "Highest_score")[["Player", "Team", "Highest_score"]]

plt.figure(figsize=(10, 5))
sns.barplot(x="Highest_score", y="Player", data=top_highest_scores, color= 'darkblue')
plt.xlabel("Highest Individual Score")
plt.ylabel("Player")
plt.title("Top 10 Highest Individual Scores in ODI")
plt.show()

top_highest_scores
# Out:
#              Player Team  Highest_score
# 251   Fakhar Zaman   PAK            210
# 394   Fakhar Zaman   PAK            193
# 11      MJ Guptill    NZ            189
# 392       JN Malan    SA            177
# 213        E Lewis    WI            176
# 27     WU Tharanga    SL            174
# 402    JS Malhotra   USA            173
# 157       AD Hales   ENG            171
# 300        SD Hope    WI            170
# 0    KC Sangakkara    SL            169

# %%
top_scores_yearly = df.loc[df.groupby("Year")["Highest_score"].idxmax(), ["Year", "Player", "Team", "Highest_score"]]

plt.figure(figsize=(7, 5))
top_player = top_scores_yearly.iloc[5]["Year"]
colors = ["darkgreen" if player == top_player else "darkblue" for player in top_scores_yearly["Year"]]
sns.barplot(x='Year', y="Highest_score", data=top_scores_yearly, palette= colors)

plt.xlabel("Year")
plt.ylabel("Highest Individual Score")
plt.title("Highest Individual Scores Per Year in ODI")
plt.xticks(rotation=45)
plt.show()

top_scores_yearly
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_13220\2015228409.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Year', y="Highest_score", data=top_scores_yearly, palette= colors)
#      Year         Player Team  Highest_score
# 11   2013    MJ Guptill    NZ            189
# 65   2014      D Ramdin    WI            169
# 107  2015   Tamim Iqbal   BAN            132
# 157  2016      AD Hales   ENG            171
# 213  2017       E Lewis    WI            176
# 251  2018  Fakhar Zaman   PAK            210
# 300  2019       SD Hope    WI            170
# 354  2020   PR Stirling   IRE            142
# 394  2021  Fakhar Zaman   PAK            193
# 460  2022    JC Buttler   ENG            162

# %%
yearly_boundaries = df.groupby('Year')['Boundary%'].mean().reset_index()

plt.figure(figsize= (7,3))
sns.lineplot(x="Year", y="Boundary%", data=yearly_boundaries, marker="o", color="darkgreen", label="Boundary %")

plt.xlabel("Year")
plt.ylabel("Boundary Percentage")
plt.title("Yearly Trend of Boundary Percentage in ODI")
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.suptitle("Univariate Analysis of ODI Batting Performance", fontsize=16)

plt.subplot(2, 2, 1)
sns.histplot(df["average"], bins=10, kde=True, color="darkblue")
plt.title("Distribution of Batting Average")
plt.xlabel("Batting Average")
plt.ylabel("Frequency")

plt.subplot(2, 2, 2)
sns.boxplot(x=df["Strike_rate"], color="lightblue")
plt.title("Boxplot of Strike Rate")
plt.xlabel("Strike Rate")

plt.subplot(2, 2, 3)
sns.histplot(df["runs"], bins=10, kde=True, color="darkgreen")
plt.title("Distribution of Runs")
plt.xlabel("Total Runs")
plt.ylabel("Frequency")

plt.subplot(2, 2, 4)
sns.kdeplot(df["Highest_score"], color="darkblue")
plt.title("Density Plot of Highest Individual Score")
plt.xlabel("Highest Score")

plt.tight_layout()
plt.show()

# %%
df["average"] = pd.to_numeric(df["average"], errors="coerce")
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_13220\3018834329.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["average"] = pd.to_numeric(df["average"], errors="coerce")

# %%
plt.figure(figsize=(3,3))
plt.pie(x=[df['6s'].sum(), df['4s'].sum()], labels=['6s', '4s'], colors=['darkblue', 'darkgreen'], autopct='%1.1f%%', explode=(0.1,0), shadow=True)
plt.title('contribution of Boundaries in T20')
plt.show()

# %%
plt.figure(figsize=(3,3))
plt.pie(x=[df['100s'].sum(), df['50s'].sum()], labels=['100s', '50s'], colors=['darkblue', 'darkgreen'], autopct='%1.1f%%', explode=(0.1,0), shadow=True)
plt.title("Contribution of 100s and 50s in ODI")
plt.show()

# %%
_100s = df.groupby('Player')[['100s']].sum().reset_index().sort_values(by= '100s', ascending=False)
print(_100s.head(10))
print('----------------------------------------------')
_50s = df.groupby('Player')[['50s']].sum().reset_index().sort_values(by= '50s', ascending=False)
print(_50s.head(10))
# Out:
#             Player  100s
# 163     RG Sharma     10
# 89    JM Bairstow      8
# 86        JE Root      8
# 171      S Dhawan      7
# 30     Babar Azam      7
# 88         JJ Roy      7
# 211       V Kohli      7
# 207   Tamim Iqbal      6
# 72        HM Amla      6
# 57   Fakhar Zaman      6
# ----------------------------------------------
#                Player  50s
# 52        EJG Morgan    20
# 5         AD Mathews    18
# 86           JE Root    16
# 207      Tamim Iqbal    16
# 144  Mushfiqur Rahim    14
# 88            JJ Roy    14
# 85        JC Buttler    14
# 211          V Kohli    14
# 171         S Dhawan    12
# 159        Q de Kock    12

# %%
plt.figure(figsize=(10, 6))
plt.subplot(2, 2, 1)
top_player = _100s.iloc[3]["Player"]
colors = ["darkgreen" if player == top_player else "darkblue" for player in _100s["Player"]]
sns.barplot(x=_100s['Player'][:5], y=_100s['100s'], palette=colors)
plt.title("Most number of centuries in ODI")
plt.xlabel("Player_name")
plt.ylabel("No.of centuries")
plt.xticks(rotation=45)

plt.subplot(2,2,2)
top_player = _50s.iloc[1]["Player"]
colors = ["darkgreen" if player == top_player else "darkblue" for player in _50s["Player"]]
sns.barplot(x=_50s['Player'][:5], y= _50s['50s'], palette=colors)
plt.title("Most number of Half-centuries ODI")
plt.xlabel("Player_name")
plt.ylabel("No.of centuries")
plt.xticks(rotation=45)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_13220\2347756872.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=_100s['Player'][:5], y=_100s['100s'], palette=colors)
# C:\Users\DELL\AppData\Local\Temp\ipykernel_13220\2347756872.py:5: UserWarning: The palette list has more values (218) than needed (5), which may not be intended.
#   sns.barplot(x=_100s['Player'][:5], y=_100s['100s'], palette=colors)
# C:\Users\DELL\AppData\Local\Temp\ipykernel_13220\2347756872.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=_50s['Player'][:5], y= _50s['50s'], palette=colors)
# ...

# %%
top_scorers = df.groupby(["Year", "Player"]).agg({
    "runs": "sum",
    "average": "mean",
    "Strike_rate": "mean",
    "Highest_score": "max",
    "100s": "sum",
    "50s": "sum"
}).reset_index()

top_scorers_by_season = top_scorers.loc[top_scorers.groupby("Year")["runs"].idxmax()]
top_scorers_by_season
# Out:
#      Year          Player  runs  average  Strike_rate  Highest_score  100s  \
# 23   2013  KC Sangakkara    772    77.20        91.69            169     2
# 68   2014   F du Plessis    618    77.25        94.64            126     3
# 127  2015  KS Williamson    676    67.60        92.48            118     1
# 178  2016   LD Chandimal    606    60.60        77.79            102     2
# 247  2017        V Kohli    832   104.00       101.71            131     3
# 269  2018    Imam-ul-Haq    620    68.89        86.35            128     3
# 339  2019        SD Hope    779    51.93        82.00            170     2
# 379  2020    SW Billings    315    78.75        95.74            118     1
# 402  2021       JN Malan    493    98.60        92.84            177     2
# 442  2022     CS MacLeod    736    49.07        82.42            133     2
#
#      50s
# 23     5
# 68     3
# 127    5
# 178    5
# 247    5
# 269    3
# 339    5
# 379    2
# 402    2
# 442    5

# %%
fig, ax1 = plt.subplots(figsize=(8, 4))
sns.barplot(x= top_scorers_by_season['Player'], y= top_scorers_by_season['runs'], color= 'darkblue', ax=ax1)
ax1.set_ylabel("Total Runs")
ax1.set_xlabel("Player")
plt.xticks(rotation=45)


ax2 = ax1.twinx()
sns.lineplot(x=top_scorers_by_season['Player'], y=top_scorers_by_season['average'], marker='s' ,color = 'darkred', label='Average', ax=ax2)
sns.lineplot(x=top_scorers_by_season['Player'], y=top_scorers_by_season['Strike_rate'], marker='o' ,color = 'darkgreen', label='Strike_rate', ax=ax2)
ax2.set_ylabel("Average and Strike rate")
ax2.set_xlabel("Player")

ax2.legend()
plt.show()

# %% [markdown]
# * Weight Breakdown:
# * 40% - Batting Average (Most crucial metric)
# * 30% - Strike Rate (Reflects scoring speed)
# * 20% - Runs per Innings (Consistency)
# * 10% - Boundary Percentage (Aggression)

# %%
df["Runs_per_Innings"] = df["runs"] / df["innings"]
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_13220\86516292.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Runs_per_Innings"] = df["runs"] / df["innings"]

# %%
import numpy as np
df = df.replace([np.inf, -np.inf], np.nan).dropna()

# %%
w1 = 0.2
w2 = 0.4
w3 = 0.3
w4 = 0.1
df["Batting_Score"] = (w1 * df['runs']) + (w2 * df['average']) + (w3 * df['Strike_rate']) + (w4 * df['Boundary%'])
top_players = df.nlargest(10, "Batting_Score")[["Player", "Team", "Batting_Score"]]
top_players
# Out:
#                Player Team  Batting_Score
# 200          V Kohli   IND        243.393
# 303  Shakib Al Hasan   BAN        219.342
# 0      KC Sangakkara    SL        217.606
# 305           JJ Roy   ENG        213.445
# 302       Babar Azam   PAK        207.302
# 304      JM Bairstow   ENG        206.631
# 301          JE Root   ENG        206.524
# 300          SD Hope    WI        205.588
# 307          V Kohli   IND        198.876
# 201         S Dhawan   IND        197.053

# %%
top_players.to_csv('top_5_bat_odi.csv')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Ensure 'Year' is numeric and sorted correctly
df["Year"] = pd.to_numeric(df["Year"], errors="coerce")
yearly_boundaries = df.groupby("Year")["Boundary%"].mean().reset_index()

# Identify the year with the highest boundary percentage
max_boundary_year = yearly_boundaries.loc[yearly_boundaries["Boundary%"].idxmax()]

# Create figure
plt.figure(figsize=(5, 3))

# Line plot for boundary percentage trend
sns.lineplot(x="Year", y="Boundary%", data=yearly_boundaries, marker="o", color="green", label="Boundary %", linewidth=2.5)

# Highlight the highest boundary percentage
plt.scatter(max_boundary_year["Year"], max_boundary_year["Boundary%"], color="red", s=100, label="Highest %")  
'''plt.text(max_boundary_year["Year"], max_boundary_year["Boundary%"] + 0.5,  
         f'{max_boundary_year["Boundary%"]:.2f}%',  
         color="red", fontsize=12, fontweight="bold")'''

# Formatting
plt.xlabel("Year")
plt.ylabel("Boundary Percentage")
plt.title("Yearly Trend of Boundary Percentage in ODI")
plt.xticks(rotation=45)  # Rotate labels for better readability
plt.legend()
plt.grid(True, linestyle="--", alpha=0.6)  # Add a light grid

# Show plot
plt.show()
