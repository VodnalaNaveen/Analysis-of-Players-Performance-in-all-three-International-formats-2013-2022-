# %%
import pandas as pd

# %%
df = pd.read_csv(r'batting(test).csv')
df
# Out:
#                           player  matches  inn  no   runs   hs    avg      bf  \
# 0                  IR Bell (ENG)        7   14   1  635.0  113  48.84  1382.0
# 1                  JE Root (ENG)        7   14   1  582.0  180  44.76  1256.0
# 2                  AN Cook (ENG)        7   14   0  494.0  130  35.28  1178.0
# 3                IJL Trott (ENG)        7   14   0  492.0   76  35.14  1000.0
# 4                SR Watson (AUS)        5   10   0  418.0  176  41.80   650.0
# ..                           ...      ...  ...  ..    ...  ...    ...     ...
# 484            MG Bracewell (NZ)        2    4   0   96.0   49  24.00   163.0
# 485  Najmul Hossain Shanto (BAN)        4    7   0   96.0   42  13.71   268.0
# 486           KS Williamson (NZ)        2    4   0   96.0   48  24.00   235.0
# 487               AT Carey (AUS)        2    3   1   89.0   45  44.50   136.0
# 488              TG Southee (NZ)        3    6   0   86.0   33  14.33    94.0
#
#         sr  _100  _50   _0   _4s  _6s  season
# 0    45.94   3.0  2.0  0.0  85.0  1.0  2013.0
# 1    46.33   2.0  2.0  0.0  67.0  2.0  2013.0
# 2    41.93   1.0  3.0  1.0  59.0  0.0  2013.0
# 3    49.20   0.0  4.0  2.0  65.0  0.0  2013.0
# 4    64.30   1.0  1.0  0.0  57.0  2.0  2013.0
# ..     ...   ...  ...  ...   ...  ...     ...
# 484  58.89   0.0  0.0  0.0  15.0  2.0  2022.0
# 485  35.82   0.0  0.0  1.0  16.0  0.0  2022.0
# 486  40.85   0.0  0.0  0.0  15.0  0.0  2022.0
# 487  65.44   0.0  0.0  0.0  10.0  0.0  2022.0
# 488  91.48   0.0  0.0  1.0  14.0  1.0  2022.0
#
# [489 rows x 15 columns]

# %%
df[['player', 'Team']] = df['player'].str.split('(', n=1, expand=True)
df
# Out:
#                      player  matches  inn  no   runs   hs    avg      bf  \
# 0                  IR Bell         7   14   1  635.0  113  48.84  1382.0
# 1                  JE Root         7   14   1  582.0  180  44.76  1256.0
# 2                  AN Cook         7   14   0  494.0  130  35.28  1178.0
# 3                IJL Trott         7   14   0  492.0   76  35.14  1000.0
# 4                SR Watson         5   10   0  418.0  176  41.80   650.0
# ..                      ...      ...  ...  ..    ...  ...    ...     ...
# 484           MG Bracewell         2    4   0   96.0   49  24.00   163.0
# 485  Najmul Hossain Shanto         4    7   0   96.0   42  13.71   268.0
# 486          KS Williamson         2    4   0   96.0   48  24.00   235.0
# 487               AT Carey         2    3   1   89.0   45  44.50   136.0
# 488             TG Southee         3    6   0   86.0   33  14.33    94.0
#
#         sr  _100  _50   _0   _4s  _6s  season  Team
# 0    45.94   3.0  2.0  0.0  85.0  1.0  2013.0  ENG)
# 1    46.33   2.0  2.0  0.0  67.0  2.0  2013.0  ENG)
# 2    41.93   1.0  3.0  1.0  59.0  0.0  2013.0  ENG)
# 3    49.20   0.0  4.0  2.0  65.0  0.0  2013.0  ENG)
# 4    64.30   1.0  1.0  0.0  57.0  2.0  2013.0  AUS)
# ..     ...   ...  ...  ...   ...  ...     ...   ...
# 484  58.89   0.0  0.0  0.0  15.0  2.0  2022.0   NZ)
# 485  35.82   0.0  0.0  1.0  16.0  0.0  2022.0  BAN)
# 486  40.85   0.0  0.0  0.0  15.0  0.0  2022.0   NZ)
# 487  65.44   0.0  0.0  0.0  10.0  0.0  2022.0  AUS)
# 488  91.48   0.0  0.0  1.0  14.0  1.0  2022.0   NZ)
#
# [489 rows x 16 columns]

# %%
df['Team'] = df['Team'].str.replace(')','')
df
# Out:
#                      player  matches  inn  no   runs   hs    avg      bf  \
# 0                  IR Bell         7   14   1  635.0  113  48.84  1382.0
# 1                  JE Root         7   14   1  582.0  180  44.76  1256.0
# 2                  AN Cook         7   14   0  494.0  130  35.28  1178.0
# 3                IJL Trott         7   14   0  492.0   76  35.14  1000.0
# 4                SR Watson         5   10   0  418.0  176  41.80   650.0
# ..                      ...      ...  ...  ..    ...  ...    ...     ...
# 484           MG Bracewell         2    4   0   96.0   49  24.00   163.0
# 485  Najmul Hossain Shanto         4    7   0   96.0   42  13.71   268.0
# 486          KS Williamson         2    4   0   96.0   48  24.00   235.0
# 487               AT Carey         2    3   1   89.0   45  44.50   136.0
# 488             TG Southee         3    6   0   86.0   33  14.33    94.0
#
#         sr  _100  _50   _0   _4s  _6s  season Team
# 0    45.94   3.0  2.0  0.0  85.0  1.0  2013.0  ENG
# 1    46.33   2.0  2.0  0.0  67.0  2.0  2013.0  ENG
# 2    41.93   1.0  3.0  1.0  59.0  0.0  2013.0  ENG
# 3    49.20   0.0  4.0  2.0  65.0  0.0  2013.0  ENG
# 4    64.30   1.0  1.0  0.0  57.0  2.0  2013.0  AUS
# ..     ...   ...  ...  ...   ...  ...     ...  ...
# 484  58.89   0.0  0.0  0.0  15.0  2.0  2022.0   NZ
# 485  35.82   0.0  0.0  1.0  16.0  0.0  2022.0  BAN
# 486  40.85   0.0  0.0  0.0  15.0  0.0  2022.0   NZ
# 487  65.44   0.0  0.0  0.0  10.0  0.0  2022.0  AUS
# 488  91.48   0.0  0.0  1.0  14.0  1.0  2022.0   NZ
#
# [489 rows x 16 columns]

# %%
df.columns
# Out:
# Index(['player', 'matches', 'inn', 'no', 'runs', 'hs', 'avg', 'bf', 'sr',
#        '_100', '_50', '_0', '_4s', '_6s', 'season', 'Team'],
#       dtype='object')

# %%
df = df.reindex(columns=['player','Team', 'matches', 'inn', 'no', 'runs', 'hs', 'avg', 'bf', 'sr',
       '_100', '_50', '_0', '_4s', '_6s', 'season'])

# %%
df
# Out:
#                      player Team  matches  inn  no   runs   hs    avg      bf  \
# 0                  IR Bell   ENG        7   14   1  635.0  113  48.84  1382.0
# 1                  JE Root   ENG        7   14   1  582.0  180  44.76  1256.0
# 2                  AN Cook   ENG        7   14   0  494.0  130  35.28  1178.0
# 3                IJL Trott   ENG        7   14   0  492.0   76  35.14  1000.0
# 4                SR Watson   AUS        5   10   0  418.0  176  41.80   650.0
# ..                      ...  ...      ...  ...  ..    ...  ...    ...     ...
# 484           MG Bracewell    NZ        2    4   0   96.0   49  24.00   163.0
# 485  Najmul Hossain Shanto   BAN        4    7   0   96.0   42  13.71   268.0
# 486          KS Williamson    NZ        2    4   0   96.0   48  24.00   235.0
# 487               AT Carey   AUS        2    3   1   89.0   45  44.50   136.0
# 488             TG Southee    NZ        3    6   0   86.0   33  14.33    94.0
#
#         sr  _100  _50   _0   _4s  _6s  season
# 0    45.94   3.0  2.0  0.0  85.0  1.0  2013.0
# 1    46.33   2.0  2.0  0.0  67.0  2.0  2013.0
# 2    41.93   1.0  3.0  1.0  59.0  0.0  2013.0
# 3    49.20   0.0  4.0  2.0  65.0  0.0  2013.0
# 4    64.30   1.0  1.0  0.0  57.0  2.0  2013.0
# ..     ...   ...  ...  ...   ...  ...     ...
# 484  58.89   0.0  0.0  0.0  15.0  2.0  2022.0
# 485  35.82   0.0  0.0  1.0  16.0  0.0  2022.0
# 486  40.85   0.0  0.0  0.0  15.0  0.0  2022.0
# 487  65.44   0.0  0.0  0.0  10.0  0.0  2022.0
# 488  91.48   0.0  0.0  1.0  14.0  1.0  2022.0
#
# [489 rows x 16 columns]

# %%
df = df.rename(columns={'inn':'innings',
                   'no':'Not_out',
                   'hs':'Highest_score',
                   'avg':'average',
                   'bf':'Balls_faced',
                   'sr':'Strike_rate',
                   '_100':'100s',
                   '_50':'50s',
                   '_0':'Duck_out',
                   '_4s':'4s',
                   '_6s':'6s',
                   'season':'Year'})
df
# Out:
#                      player Team  matches  innings  Not_out   runs  \
# 0                  IR Bell   ENG        7       14        1  635.0
# 1                  JE Root   ENG        7       14        1  582.0
# 2                  AN Cook   ENG        7       14        0  494.0
# 3                IJL Trott   ENG        7       14        0  492.0
# 4                SR Watson   AUS        5       10        0  418.0
# ..                      ...  ...      ...      ...      ...    ...
# 484           MG Bracewell    NZ        2        4        0   96.0
# 485  Najmul Hossain Shanto   BAN        4        7        0   96.0
# 486          KS Williamson    NZ        2        4        0   96.0
# 487               AT Carey   AUS        2        3        1   89.0
# 488             TG Southee    NZ        3        6        0   86.0
#
#     Highest_score average  Balls_faced  Strike_rate  100s  50s  Duck_out  \
# 0             113   48.84       1382.0        45.94   3.0  2.0       0.0
# 1             180   44.76       1256.0        46.33   2.0  2.0       0.0
# 2             130   35.28       1178.0        41.93   1.0  3.0       1.0
# 3              76   35.14       1000.0        49.20   0.0  4.0       2.0
# 4             176   41.80        650.0        64.30   1.0  1.0       0.0
# ..            ...     ...          ...          ...   ...  ...       ...
# 484            49   24.00        163.0        58.89   0.0  0.0       0.0
# 485            42   13.71        268.0        35.82   0.0  0.0       1.0
# 486            48   24.00        235.0        40.85   0.0  0.0       0.0
# 487            45   44.50        136.0        65.44   0.0  0.0       0.0
# 488            33   14.33         94.0        91.48   0.0  0.0       1.0
#
#        4s   6s    Year
# 0    85.0  1.0  2013.0
# 1    67.0  2.0  2013.0
# 2    59.0  0.0  2013.0
# 3    65.0  0.0  2013.0
# 4    57.0  2.0  2013.0
# ..    ...  ...     ...
# 484  15.0  2.0  2022.0
# 485  16.0  0.0  2022.0
# 486  15.0  0.0  2022.0
# 487  10.0  0.0  2022.0
# 488  14.0  1.0  2022.0
#
# [489 rows x 16 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 489 entries, 0 to 488
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   player         489 non-null    object
#  1   Team           489 non-null    object
#  2   matches        489 non-null    int64
#  3   innings        489 non-null    int64
#  4   Not_out        489 non-null    int64
#  5   runs           485 non-null    float64
#  6   Highest_score  486 non-null    object
#  7   average        481 non-null    object
#  8   Balls_faced    480 non-null    float64
#  9   Strike_rate    480 non-null    float64
#  10  100s           480 non-null    float64
#  11  50s            480 non-null    float64
#  12  Duck_out       480 non-null    float64
#  13  4s             480 non-null    float64
#  14  6s             480 non-null    float64
#  15  Year           480 non-null    float64
# dtypes: float64(9), int64(3), object(4)
# memory usage: 61.3+ KB

# %%
df.isna().sum()
# Out:
# player           0
# Team             0
# matches          0
# innings          0
# Not_out          0
# runs             4
# Highest_score    3
# average          8
# Balls_faced      9
# Strike_rate      9
# 100s             9
# 50s              9
# Duck_out         9
# 4s               9
# 6s               9
# Year             9
# dtype: int64

# %%
col = ['Balls_faced','100s', '50s', 'Duck_out', '4s', '6s']
for i in col:
    df[i] = df[i].fillna(0)

# %%
df.isna().sum()
# Out:
# player           0
# Team             0
# matches          0
# innings          0
# Not_out          0
# runs             4
# Highest_score    3
# average          8
# Balls_faced      0
# Strike_rate      9
# 100s             0
# 50s              0
# Duck_out         0
# 4s               0
# 6s               0
# Year             9
# dtype: int64

# %%
df = df.dropna(subset = ['runs'])

# %%
df.isna().sum()
# Out:
# player           0
# Team             0
# matches          0
# innings          0
# Not_out          0
# runs             0
# Highest_score    0
# average          4
# Balls_faced      0
# Strike_rate      5
# 100s             0
# 50s              0
# Duck_out         0
# 4s               0
# 6s               0
# Year             5
# dtype: int64

# %%
df['Dismissals'] = df['innings'] - df['Not_out']
df['average'] = round(df['runs']/df['Dismissals'],2)
df['Strike_rate'] = round((df['runs']/df['Balls_faced'])*100,2)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_8416\1392224033.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Dismissals'] = df['innings'] - df['Not_out']
# C:\Users\DELL\AppData\Local\Temp\ipykernel_8416\1392224033.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['average'] = round(df['runs']/df['Dismissals'],2)
# C:\Users\DELL\AppData\Local\Temp\ipykernel_8416\1392224033.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Strike_rate'] = round((df['runs']/df['Balls_faced'])*100,2)

# %%
df
# Out:
#                      player Team  matches  innings  Not_out   runs  \
# 0                  IR Bell   ENG        7       14        1  635.0
# 1                  JE Root   ENG        7       14        1  582.0
# 2                  AN Cook   ENG        7       14        0  494.0
# 3                IJL Trott   ENG        7       14        0  492.0
# 4                SR Watson   AUS        5       10        0  418.0
# ..                      ...  ...      ...      ...      ...    ...
# 484           MG Bracewell    NZ        2        4        0   96.0
# 485  Najmul Hossain Shanto   BAN        4        7        0   96.0
# 486          KS Williamson    NZ        2        4        0   96.0
# 487               AT Carey   AUS        2        3        1   89.0
# 488             TG Southee    NZ        3        6        0   86.0
#
#     Highest_score  average  Balls_faced  Strike_rate  100s  50s  Duck_out  \
# 0             113    48.85       1382.0        45.95   3.0  2.0       0.0
# 1             180    44.77       1256.0        46.34   2.0  2.0       0.0
# 2             130    35.29       1178.0        41.94   1.0  3.0       1.0
# 3              76    35.14       1000.0        49.20   0.0  4.0       2.0
# 4             176    41.80        650.0        64.31   1.0  1.0       0.0
# ..            ...      ...          ...          ...   ...  ...       ...
# 484            49    24.00        163.0        58.90   0.0  0.0       0.0
# 485            42    13.71        268.0        35.82   0.0  0.0       1.0
# 486            48    24.00        235.0        40.85   0.0  0.0       0.0
# 487            45    44.50        136.0        65.44   0.0  0.0       0.0
# 488            33    14.33         94.0        91.49   0.0  0.0       1.0
#
#        4s   6s    Year  Dismissals
# 0    85.0  1.0  2013.0          13
# 1    67.0  2.0  2013.0          13
# 2    59.0  0.0  2013.0          14
# 3    65.0  0.0  2013.0          14
# 4    57.0  2.0  2013.0          10
# ..    ...  ...     ...         ...
# 484  15.0  2.0  2022.0           4
# 485  16.0  0.0  2022.0           7
# 486  15.0  0.0  2022.0           4
# 487  10.0  0.0  2022.0           2
# 488  14.0  1.0  2022.0           6
#
# [485 rows x 17 columns]

# %%
df.isna().sum()
# Out:
# player           0
# Team             0
# matches          0
# innings          0
# Not_out          0
# runs             0
# Highest_score    0
# average          0
# Balls_faced      0
# Strike_rate      0
# 100s             0
# 50s              0
# Duck_out         0
# 4s               0
# 6s               0
# Year             5
# Dismissals       0
# dtype: int64

# %%
df['Year'] = df['Year'].ffill()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_8416\708031714.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Year'] = df['Year'].ffill()

# %%
df.isna().sum()
# Out:
# player           0
# Team             0
# matches          0
# innings          0
# Not_out          0
# runs             0
# Highest_score    0
# average          0
# Balls_faced      0
# Strike_rate      0
# 100s             0
# 50s              0
# Duck_out         0
# 4s               0
# 6s               0
# Year             0
# Dismissals       0
# dtype: int64

# %%
df
# Out:
#                      player Team  matches  innings  Not_out   runs  \
# 0                  IR Bell   ENG        7       14        1  635.0
# 1                  JE Root   ENG        7       14        1  582.0
# 2                  AN Cook   ENG        7       14        0  494.0
# 3                IJL Trott   ENG        7       14        0  492.0
# 4                SR Watson   AUS        5       10        0  418.0
# ..                      ...  ...      ...      ...      ...    ...
# 484           MG Bracewell    NZ        2        4        0   96.0
# 485  Najmul Hossain Shanto   BAN        4        7        0   96.0
# 486          KS Williamson    NZ        2        4        0   96.0
# 487               AT Carey   AUS        2        3        1   89.0
# 488             TG Southee    NZ        3        6        0   86.0
#
#     Highest_score  average  Balls_faced  Strike_rate  100s  50s  Duck_out  \
# 0             113    48.85       1382.0        45.95   3.0  2.0       0.0
# 1             180    44.77       1256.0        46.34   2.0  2.0       0.0
# 2             130    35.29       1178.0        41.94   1.0  3.0       1.0
# 3              76    35.14       1000.0        49.20   0.0  4.0       2.0
# 4             176    41.80        650.0        64.31   1.0  1.0       0.0
# ..            ...      ...          ...          ...   ...  ...       ...
# 484            49    24.00        163.0        58.90   0.0  0.0       0.0
# 485            42    13.71        268.0        35.82   0.0  0.0       1.0
# 486            48    24.00        235.0        40.85   0.0  0.0       0.0
# 487            45    44.50        136.0        65.44   0.0  0.0       0.0
# 488            33    14.33         94.0        91.49   0.0  0.0       1.0
#
#        4s   6s    Year  Dismissals
# 0    85.0  1.0  2013.0          13
# 1    67.0  2.0  2013.0          13
# 2    59.0  0.0  2013.0          14
# 3    65.0  0.0  2013.0          14
# 4    57.0  2.0  2013.0          10
# ..    ...  ...     ...         ...
# 484  15.0  2.0  2022.0           4
# 485  16.0  0.0  2022.0           7
# 486  15.0  0.0  2022.0           4
# 487  10.0  0.0  2022.0           2
# 488  14.0  1.0  2022.0           6
#
# [485 rows x 17 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 485 entries, 0 to 488
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   player         485 non-null    object
#  1   Team           485 non-null    object
#  2   matches        485 non-null    int64
#  3   innings        485 non-null    int64
#  4   Not_out        485 non-null    int64
#  5   runs           485 non-null    float64
#  6   Highest_score  485 non-null    object
#  7   average        485 non-null    float64
#  8   Balls_faced    485 non-null    float64
#  9   Strike_rate    485 non-null    float64
#  10  100s           485 non-null    float64
#  11  50s            485 non-null    float64
#  12  Duck_out       485 non-null    float64
#  13  4s             485 non-null    float64
#  14  6s             485 non-null    float64
#  15  Year           485 non-null    float64
#  16  Dismissals     485 non-null    int64
# dtypes: float64(10), int64(4), object(3)
# memory usage: 68.2+ KB

# %%
df["Highest_score"] = df["Highest_score"].str.replace("*", "", regex=False).astype(int)
df["average"] = pd.to_numeric(df["average"], errors="coerce")
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_8416\1065879819.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Highest_score"] = df["Highest_score"].str.replace("*", "", regex=False).astype(int)
# C:\Users\DELL\AppData\Local\Temp\ipykernel_8416\1065879819.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["average"] = pd.to_numeric(df["average"], errors="coerce")

# %%
col = ['runs', 'Balls_faced', '100s',	'50s', 'Duck_out', '4s', '6s', 'Year']
for i in col:
    df[i] = df[i].astype('int')
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_8416\2952924069.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[i] = df[i].astype('int')
# C:\Users\DELL\AppData\Local\Temp\ipykernel_8416\2952924069.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[i] = df[i].astype('int')
# C:\Users\DELL\AppData\Local\Temp\ipykernel_8416\2952924069.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[i] = df[i].astype('int')
# C:\Users\DELL\AppData\Local\Temp\ipykernel_8416\2952924069.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[i] = df[i].astype('int')
# C:\Users\DELL\AppData\Local\Temp\ipykernel_8416\2952924069.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[i] = df[i].astype('int')
# C:\Users\DELL\AppData\Local\Temp\ipykernel_8416\2952924069.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[i] = df[i].astype('int')
# C:\Users\DELL\AppData\Local\Temp\ipykernel_8416\2952924069.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[i] = df[i].astype('int')
# C:\Users\DELL\AppData\Local\Temp\ipykernel_8416\2952924069.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[i] = df[i].astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 485 entries, 0 to 488
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   player         485 non-null    object
#  1   Team           485 non-null    object
#  2   matches        485 non-null    int64
#  3   innings        485 non-null    int64
#  4   Not_out        485 non-null    int64
#  5   runs           485 non-null    int32
#  6   Highest_score  485 non-null    int32
#  7   average        485 non-null    float64
#  8   Balls_faced    485 non-null    int32
#  9   Strike_rate    485 non-null    float64
#  10  100s           485 non-null    int32
#  11  50s            485 non-null    int32
#  12  Duck_out       485 non-null    int32
#  13  4s             485 non-null    int32
#  14  6s             485 non-null    int32
#  15  Year           485 non-null    int32
#  16  Dismissals     485 non-null    int64
# dtypes: float64(2), int32(9), int64(4), object(2)
# memory usage: 51.2+ KB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df["Boundary%"] = round(((df["4s"] * 4) + (df["6s"] * 6)) / df["runs"] * 100,2)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_8416\3669843693.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Boundary%"] = round(((df["4s"] * 4) + (df["6s"] * 6)) / df["runs"] * 100,2)

# %%
df
# Out:
#                      player Team  matches  innings  Not_out  runs  \
# 0                  IR Bell   ENG        7       14        1   635
# 1                  JE Root   ENG        7       14        1   582
# 2                  AN Cook   ENG        7       14        0   494
# 3                IJL Trott   ENG        7       14        0   492
# 4                SR Watson   AUS        5       10        0   418
# ..                      ...  ...      ...      ...      ...   ...
# 484           MG Bracewell    NZ        2        4        0    96
# 485  Najmul Hossain Shanto   BAN        4        7        0    96
# 486          KS Williamson    NZ        2        4        0    96
# 487               AT Carey   AUS        2        3        1    89
# 488             TG Southee    NZ        3        6        0    86
#
#      Highest_score  average  Balls_faced  Strike_rate  100s  50s  Duck_out  \
# 0              113    48.85         1382        45.95     3    2         0
# 1              180    44.77         1256        46.34     2    2         0
# 2              130    35.29         1178        41.94     1    3         1
# 3               76    35.14         1000        49.20     0    4         2
# 4              176    41.80          650        64.31     1    1         0
# ..             ...      ...          ...          ...   ...  ...       ...
# 484             49    24.00          163        58.90     0    0         0
# 485             42    13.71          268        35.82     0    0         1
# 486             48    24.00          235        40.85     0    0         0
# 487             45    44.50          136        65.44     0    0         0
# 488             33    14.33           94        91.49     0    0         1
#
#      4s  6s  Year  Dismissals  Boundary%
# 0    85   1  2013          13      54.49
# 1    67   2  2013          13      48.11
# 2    59   0  2013          14      47.77
# 3    65   0  2013          14      52.85
# 4    57   2  2013          10      57.42
# ..   ..  ..   ...         ...        ...
# 484  15   2  2022           4      75.00
# 485  16   0  2022           7      66.67
# 486  15   0  2022           4      62.50
# 487  10   0  2022           2      44.94
# 488  14   1  2022           6      72.09
#
# [485 rows x 18 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df['Team'].nunique()
# Out:
# 12

# %%
df['Team'].unique()
# Out:
# array(['ENG', 'AUS', 'ZIM', 'PAK', 'BAN', 'NZ', 'SL', 'WI', 'IND', 'SA',
#        'IRE', 'AFG'], dtype=object)

# %%
plt.figure(figsize=(10, 6))
plt.suptitle("Univariate Analysis of Test Batting Performance", fontsize=16)


plt.subplot(2, 2, 1)
sns.histplot(df["average"], bins=10, kde=True, color="darkblue")
plt.title("Distribution of Batting Average")
plt.xlabel("Batting Average")
plt.ylabel("Frequency")

plt.subplot(2, 2, 2)
sns.boxplot(x=df["Strike_rate"], color="lightblue")
plt.title("Boxplot of Strike Rate")
plt.xlabel("Strike Rate")

plt.subplot(2, 2, 3)
sns.histplot(df["runs"], bins=10, kde=True, color="darkgreen")
plt.title("Distribution of Runs")
plt.xlabel("Total Runs")
plt.ylabel("Frequency")

plt.subplot(2, 2, 4)
sns.kdeplot(df["Highest_score"], color="darkblue")
plt.title("Density Plot of Highest Individual Score")
plt.xlabel("Highest Score")

plt.tight_layout()
plt.show()

# %%
top_10_scorers = df.nlargest(10, "runs")[["player", "Team", "runs"]]

plt.figure(figsize=(5, 3))
sns.barplot(x= top_10_scorers["runs"], y= top_10_scorers["player"], color= 'darkblue')
plt.xlabel("Total Runs")
plt.ylabel("Player")
plt.title("Top 10 Players by Runs in Test")
plt.show()

top_10_scorers
# Out:
#              player Team  runs
# 100        JE Root   ENG  1001
# 101        AN Cook   ENG   907
# 50   KC Sangakkara    SL   837
# 102      SPD Smith   AUS   791
# 51         JE Root   ENG   777
# 300      SPD Smith   AUS   774
# 150    JM Bairstow   ENG   753
# 52      AD Mathews    SL   746
# 200        JE Root   ENG   729
# 439   LD Chandimal    SL   719

# %%
total_runs_by_team = df.groupby('Team')[['runs']].sum().reset_index().sort_values(by= 'runs', ascending= False).head(10)
plt.figure(figsize=(7, 5))
sns.barplot(x= total_runs_by_team['runs'], y= total_runs_by_team['Team'], color='darkblue')
plt.xlabel("Total Runs")
plt.ylabel("Team")
plt.title("Total runs by Team in Test")
plt.show()

# %%
yearly_stats = df.groupby(['Year'])[['average', 'Strike_rate']].mean().reset_index()

plt.figure(figsize=(8,3))
sns.lineplot(x="Year", y="average", data=yearly_stats, marker="o", label="Batting Average", color="darkblue")
sns.lineplot(x="Year", y="Strike_rate", data=yearly_stats, marker="s", label="Strike Rate", color="darkgreen")

plt.xlabel("Year")
plt.ylabel("Value")
plt.title("Yearly Trend of Batting Average and Strike Rate in Test")
plt.legend()
plt.grid(True)
plt.show()

# %%
top_highest_scores = df.nlargest(10, "Highest_score")[["player", "Team", "Highest_score"]]

plt.figure(figsize=(10, 5))
sns.barplot(x="Highest_score", y="player", data=top_highest_scores, color='darkblue')
plt.xlabel("Highest Individual Score")
plt.ylabel("Player")
plt.title("Top 10 Highest Individual Scores in Test")
plt.show()

top_highest_scores
# Out:
#                player Team  Highest_score
# 350        Z Crawley   ENG            267
# 152          JE Root   ENG            254
# 391  FDM Karunaratne    SL            244
# 201          AN Cook   ENG            243
# 105        Azhar Ali   PAK            226
# 121  Mohammad Hafeez   PAK            224
# 50     KC Sangakkara    SL            221
# 159      Younis Khan   PAK            218
# 102        SPD Smith   AUS            215
# 394         Abid Ali   PAK            215

# %%
top_scores_yearly = df.loc[df.groupby("Year")["Highest_score"].idxmax(), ["Year", "player", "Team", "Highest_score"]]

plt.figure(figsize=(7, 5))
top_player = top_scores_yearly.iloc[7]["Year"]
colors = ["darkgreen" if player == top_player else "darkblue" for player in top_scores_yearly["Year"]]
sns.barplot(x='Year', y="Highest_score", data=top_scores_yearly, palette=colors)

plt.xlabel("Year")
plt.ylabel("Highest Individual Score")
plt.title("Highest Individual Scores Per Year in Test")
plt.xticks(rotation=45)
plt.show()

top_scores_yearly
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_8416\2700434929.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Year', y="Highest_score", data=top_scores_yearly, palette=colors)
#      Year            player Team  Highest_score
# 11   2013      Younis Khan   PAK            200
# 50   2014    KC Sangakkara    SL            221
# 105  2015        Azhar Ali   PAK            226
# 152  2016          JE Root   ENG            254
# 201  2017          AN Cook   ENG            243
# 254  2018  FDM Karunaratne    SL            158
# 300  2019        SPD Smith   AUS            211
# 350  2020        Z Crawley   ENG            267
# 391  2021  FDM Karunaratne    SL            244
# 439  2022     LD Chandimal    SL            206

# %%
yearly_boundaries = df.groupby('Year')['Boundary%'].mean().reset_index()

plt.figure(figsize= (7,3))
sns.lineplot(x="Year", y="Boundary%", data=yearly_boundaries, marker="o", color="green", label="Boundary %")

plt.xlabel("Year")
plt.ylabel("Boundary Percentage")
plt.title("Yearly Trend of Boundary Percentage in Test")
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(3,3))
plt.pie(x=[df['6s'].sum(), df['4s'].sum()], labels=['6s', '4s'], colors=['darkblue', 'darkgreen'], autopct='%1.1f%%', explode=(0.1,0), shadow=True)
plt.title('contribution of Boundaries in Test')
plt.show()

# %%
plt.figure(figsize=(3,3))
plt.pie(x=[df['100s'].sum(), df['50s'].sum()], labels=['100s', '50s'], autopct='%1.1f%%', colors=['darkblue', 'darkgreen'], explode=(0.1,0), shadow=True)
plt.title("Contribution of 100s and 50s in Test")
plt.show()

# %%
_100s = df.groupby('player')[['100s']].sum().reset_index().sort_values(by= '100s', ascending=False)
print(_100s.head(10))
print('----------------------------------------------')
_50s = df.groupby('player')[['50s']].sum().reset_index().sort_values(by= '50s', ascending=False)
print(_50s.head(10))
# Out:
#                player  100s
# 86           JE Root     18
# 181        SPD Smith      9
# 6         AD Mathews      7
# 22         Azhar Ali      7
# 24         BA Stokes      7
# 57   FDM Karunaratne      6
# 99     KC Brathwaite      6
# 9            AN Cook      6
# 92       JM Bairstow      6
# 111     LD Chandimal      6
# ----------------------------------------------
#                player  50s
# 86           JE Root    28
# 9            AN Cook    20
# 24         BA Stokes    14
# 92       JM Bairstow    14
# 57   FDM Karunaratne    13
# 83        JC Buttler    12
# 6         AD Mathews    12
# 80       J Blackwood    11
# 99     KC Brathwaite    11
# 138    Misbah-ul-Haq    11

# %%
plt.figure(figsize=(10, 6))
plt.subplot(2, 2, 1)
top_player = _100s.iloc[3]["player"]
colors = ["darkgreen" if player == top_player else "darkblue" for player in _100s["player"]]
sns.barplot(x=_100s['player'][:5], y=_100s['100s'], palette=colors)
plt.title("Most number of centuries in Test")
plt.xlabel("Player_name")
plt.ylabel("No.of centuries")
plt.xticks(rotation=45)

plt.subplot(2,2,2)
top_player = _50s.iloc[3]["player"]
colors = ["darkgreen" if player == top_player else "darkblue" for player in _50s["player"]]
sns.barplot(x=_50s['player'][:5], y= _50s['50s'], palette= colors)
plt.title("Most number of Half-centuries in Test")
plt.xlabel("Player_name")
plt.ylabel("No.of centuries")
plt.xticks(rotation=45)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_8416\1060902155.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=_100s['player'][:5], y=_100s['100s'], palette=colors)
# C:\Users\DELL\AppData\Local\Temp\ipykernel_8416\1060902155.py:5: UserWarning: The palette list has more values (216) than needed (5), which may not be intended.
#   sns.barplot(x=_100s['player'][:5], y=_100s['100s'], palette=colors)
# C:\Users\DELL\AppData\Local\Temp\ipykernel_8416\1060902155.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=_50s['player'][:5], y= _50s['50s'], palette= colors)
# C:\Users\DELL\AppData\Local\Temp\ipykernel_8416\1060902155.py:14: UserWarning: The palette list has more values (216) than needed (5), which may not be intended.
#   sns.barplot(x=_50s['player'][:5], y= _50s['50s'], palette= colors)
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, 'AN Cook '),
#   Text(1, 0, 'BA Stokes '),
#   Text(2, 0, 'FDM Karunaratne '),
#   Text(3, 0, 'JE Root '),
#   Text(4, 0, 'JM Bairstow ')])

# %%
top_scorers = df.groupby(["Year", "player"]).agg({
    "runs": "sum",
    "Balls_faced": "sum",
    "average": "mean",
    "Strike_rate": "mean",
    "Highest_score": "max",
    "100s": "sum",
    "50s": "sum"
}).reset_index()

top_scorers_by_season = top_scorers.loc[top_scorers.groupby("Year")["runs"].idxmax()]
top_scorers_by_season
# Out:
#      Year          player  runs  Balls_faced  average  Strike_rate  \
# 14   2013        IR Bell    635         1382    48.85        45.95
# 78   2014  KC Sangakkara    837         1568    69.75        53.38
# 122  2015        JE Root   1001         1482    62.56        67.54
# 172  2016    JM Bairstow    753         1199    75.30        62.80
# 219  2017        JE Root    729         1100    60.75        66.27
# 299  2018        V Kohli    593         1025    59.30        57.85
# 343  2019      SPD Smith    774         1196   110.57        64.72
# 384  2020      Z Crawley    417          661    69.50        63.09
# 406  2021        JE Root    661         1181    66.10        55.97
# 460  2022   LD Chandimal    719         1299   102.71        55.35
#
#      Highest_score  100s  50s
# 14             113     3    2
# 78             221     2    6
# 122            182     3    6
# 172            167     2    4
# 219            190     2    5
# 299            149     2    3
# 343            211     3    3
# 384            267     1    2
# 406            180     3    1
# 460            206     2    4

# %%
fig, ax1 = plt.subplots(figsize=(12, 6))
sns.barplot(x= top_scorers_by_season['player'], y= top_scorers_by_season['runs'], color= 'darkblue', ax=ax1)
ax1.set_ylabel("Total Runs")
ax1.set_xlabel("Player")
plt.xticks(rotation=45)


ax2 = ax1.twinx()
sns.lineplot(x=top_scorers_by_season['player'], y=top_scorers_by_season['average'], marker='s', color = 'darkred', label='Average', ax=ax2)
sns.lineplot(x=top_scorers_by_season['player'], y=top_scorers_by_season['Strike_rate'], marker= 'o', color = 'darkgreen', label='Strike_rate', ax=ax2)
ax2.set_ylabel("Average and Strike rate")
ax2.set_xlabel("Player")
plt.xticks(rotation=45)
# Out:
# ([0, 1, 2, 3, 4, 5, 6, 7],
#  [Text(0, 0, 'IR Bell '),
#   Text(1, 0, 'KC Sangakkara '),
#   Text(2, 0, 'JE Root '),
#   Text(3, 0, 'JM Bairstow '),
#   Text(4, 0, 'V Kohli '),
#   Text(5, 0, 'SPD Smith '),
#   Text(6, 0, 'Z Crawley '),
#   Text(7, 0, 'LD Chandimal ')])

# %%
import numpy as np
df = df.replace([np.inf, -np.inf], np.nan).dropna()

# %%
w1 = 0.5 #runs
w2 = 0. #avg
w3 = 0.1 #strike rate
df["Batting_Score"] = (w1 * df['runs']) + (w2 * df['average']) + (w3 * df['Strike_rate'])
top_players = df.nlargest(10, "Batting_Score")[["player", "Team", "Batting_Score"]]
top_players
# Out:
#              player Team  Batting_Score
# 100        JE Root   ENG        507.254
# 101        AN Cook   ENG        457.748
# 50   KC Sangakkara    SL        423.838
# 102      SPD Smith   AUS        401.377
# 51         JE Root   ENG        394.303
# 300      SPD Smith   AUS        393.472
# 150    JM Bairstow   ENG        382.780
# 52      AD Mathews    SL        378.272
# 200        JE Root   ENG        371.127
# 439   LD Chandimal    SL        365.035

# %%
top_players.to_csv('top_5_bat_test.csv')
