# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_odi=pd.read_csv(r'C:\Users\vodna\OneDrive\Desktop\p\bowling(odi).csv')
df_odi
# Out:
#                   player  matches  inn  overs  maiden   runs  wkts bb_inn  \
# 0        RA Jadeja (IND)       15   15  128.5    15.0  515.0  25.0   5/36
# 1      HMRKB Herath (SL)       12   12   95.5     4.0  370.0  21.0   4/20
# 2      Saeed Ajmal (PAK)       13   13  112.4     5.0  510.0  21.0   3/25
# 3      Junaid Khan (PAK)       12   12   93.4    10.0  467.0  20.0   4/15
# 4    MJ McClenaghan (NZ)        6    6   52.0     1.0  282.0  19.0   4/43
# ..                   ...      ...  ...    ...     ...    ...   ...    ...
# 487       SI Kamea (PNG)        7    7   53.0     3.0  307.0   9.0   3/36
# 488     GJ Maxwell (AUS)       11    9   66.0     2.0  324.0   9.0   4/52
# 489       NK Patel (USA)       13   13   94.1     1.0  492.0   9.0   2/26
# 490       CA Soper (PNG)        8    8   72.0     3.0  327.0   9.0   2/27
# 491      TG Southee (NZ)        5    5   47.0     4.0  204.0   9.0   4/22
#
#        avg  econ    sr  _4w  _5w  season
# 0    20.60  3.99  30.9  1.0  1.0  2013.0
# 1    17.61  3.86  27.3  1.0  0.0  2013.0
# 2    24.28  4.52  32.1  0.0  0.0  2013.0
# 3    23.35  4.98  28.1  1.0  0.0  2013.0
# 4    14.84  5.42  16.4  2.0  0.0  2013.0
# ..     ...   ...   ...  ...  ...     ...
# 487  34.11  5.79  35.3  0.0  0.0  2022.0
# 488  36.00  4.90  44.0  1.0  0.0  2022.0
# 489  54.66  5.22  62.7  0.0  0.0  2022.0
# 490  36.33  4.54  48.0  0.0  0.0  2022.0
# 491  22.66  4.34  31.3  1.0  0.0  2022.0
#
# [492 rows x 14 columns]

# %%
df_odi.isna().sum()
# Out:
# player      0
# matches     0
# inn         0
# overs      14
# maiden     14
# runs       14
# wkts       14
# bb_inn     20
# avg        20
# econ       20
# sr         20
# _4w        20
# _5w        20
# season     20
# dtype: int64

# %%
df_odi=df_odi.dropna()

# %%
df_odi=df_odi.rename(columns= {"_5w": "5wicket_haul",
                       "_4w": "4wicket_haul",
                        "wkts": "wickets", 
                       "bb_inn": "best_bowling_innings",
                       'inn':'innings',
                       'avg':'average',
                       "econ" : 'economy',
                       'sr':'strike rate',
                       'runs':'runs conceded',
                       'season':'year'})
df_odi
# Out:
#                   player  matches  innings  overs  maiden  runs conceded  \
# 0        RA Jadeja (IND)       15       15  128.5    15.0          515.0
# 1      HMRKB Herath (SL)       12       12   95.5     4.0          370.0
# 2      Saeed Ajmal (PAK)       13       13  112.4     5.0          510.0
# 3      Junaid Khan (PAK)       12       12   93.4    10.0          467.0
# 4    MJ McClenaghan (NZ)        6        6   52.0     1.0          282.0
# ..                   ...      ...      ...    ...     ...            ...
# 487       SI Kamea (PNG)        7        7   53.0     3.0          307.0
# 488     GJ Maxwell (AUS)       11        9   66.0     2.0          324.0
# 489       NK Patel (USA)       13       13   94.1     1.0          492.0
# 490       CA Soper (PNG)        8        8   72.0     3.0          327.0
# 491      TG Southee (NZ)        5        5   47.0     4.0          204.0
#
#      wickets best_bowling_innings  average  economy  strike rate  \
# 0       25.0                 5/36    20.60     3.99         30.9
# 1       21.0                 4/20    17.61     3.86         27.3
# 2       21.0                 3/25    24.28     4.52         32.1
# 3       20.0                 4/15    23.35     4.98         28.1
# 4       19.0                 4/43    14.84     5.42         16.4
# ..       ...                  ...      ...      ...          ...
# 487      9.0                 3/36    34.11     5.79         35.3
# 488      9.0                 4/52    36.00     4.90         44.0
# 489      9.0                 2/26    54.66     5.22         62.7
# 490      9.0                 2/27    36.33     4.54         48.0
# 491      9.0                 4/22    22.66     4.34         31.3
#
#      4wicket_haul  5wicket_haul    year
# 0             1.0           1.0  2013.0
# 1             1.0           0.0  2013.0
# 2             0.0           0.0  2013.0
# 3             1.0           0.0  2013.0
# 4             2.0           0.0  2013.0
# ..            ...           ...     ...
# 487           0.0           0.0  2022.0
# 488           1.0           0.0  2022.0
# 489           0.0           0.0  2022.0
# 490           0.0           0.0  2022.0
# 491           1.0           0.0  2022.0
#
# [472 rows x 14 columns]

# %%
df_odi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 472 entries, 0 to 491
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   player                472 non-null    object
#  1   matches               472 non-null    int64
#  2   innings               472 non-null    int64
#  3   overs                 472 non-null    float64
#  4   maiden                472 non-null    float64
#  5   runs conceded         472 non-null    float64
#  6   wickets               472 non-null    float64
#  7   best_bowling_innings  472 non-null    object
#  8   average               472 non-null    float64
#  9   economy               472 non-null    float64
#  10  strike rate           472 non-null    float64
#  11  4wicket_haul          472 non-null    float64
#  12  5wicket_haul          472 non-null    float64
#  13  year                  472 non-null    float64
# dtypes: float64(10), int64(2), object(2)
# memory usage: 55.3+ KB

# %%
df_odi.columns
# Out:
# Index(['player', 'matches', 'innings', 'overs', 'maiden', 'runs conceded',
#        'wickets', 'best_bowling_innings', 'average', 'economy', 'strike rate',
#        '4wicket_haul', '5wicket_haul', 'year'],
#       dtype='object')

# %%
column=['maiden', 'runs conceded', 'wickets','4wicket_haul', '5wicket_haul', 'year']
for i in column:
    df_odi[i]=df_odi[i].astype('int')

# %%
df_odi[['player','country']]=df_odi['player'].str.split('(',n=1,expand=True)
df_odi
# Out:
#               player  matches  innings  overs  maiden  runs conceded  wickets  \
# 0         RA Jadeja        15       15  128.5      15            515       25
# 1      HMRKB Herath        12       12   95.5       4            370       21
# 2       Saeed Ajmal        13       13  112.4       5            510       21
# 3       Junaid Khan        12       12   93.4      10            467       20
# 4    MJ McClenaghan         6        6   52.0       1            282       19
# ..               ...      ...      ...    ...     ...            ...      ...
# 487        SI Kamea         7        7   53.0       3            307        9
# 488      GJ Maxwell        11        9   66.0       2            324        9
# 489        NK Patel        13       13   94.1       1            492        9
# 490        CA Soper         8        8   72.0       3            327        9
# 491      TG Southee         5        5   47.0       4            204        9
#
#     best_bowling_innings  average  economy  strike rate  4wicket_haul  \
# 0                   5/36    20.60     3.99         30.9             1
# 1                   4/20    17.61     3.86         27.3             1
# 2                   3/25    24.28     4.52         32.1             0
# 3                   4/15    23.35     4.98         28.1             1
# 4                   4/43    14.84     5.42         16.4             2
# ..                   ...      ...      ...          ...           ...
# 487                 3/36    34.11     5.79         35.3             0
# 488                 4/52    36.00     4.90         44.0             1
# 489                 2/26    54.66     5.22         62.7             0
# 490                 2/27    36.33     4.54         48.0             0
# 491                 4/22    22.66     4.34         31.3             1
#
#      5wicket_haul  year country
# 0               1  2013    IND)
# 1               0  2013     SL)
# 2               0  2013    PAK)
# 3               0  2013    PAK)
# 4               0  2013     NZ)
# ..            ...   ...     ...
# 487             0  2022    PNG)
# 488             0  2022    AUS)
# 489             0  2022    USA)
# 490             0  2022    PNG)
# 491             0  2022     NZ)
#
# [472 rows x 15 columns]

# %%
df_odi['country']=df_odi['country'].str.replace(')','')
df_odi['country']=df_odi['country'].str.replace('3 (','')
df_odi['country']=df_odi['country'].str.replace('1 (','')
df_odi
# Out:
#               player  matches  innings  overs  maiden  runs conceded  wickets  \
# 0         RA Jadeja        15       15  128.5      15            515       25
# 1      HMRKB Herath        12       12   95.5       4            370       21
# 2       Saeed Ajmal        13       13  112.4       5            510       21
# 3       Junaid Khan        12       12   93.4      10            467       20
# 4    MJ McClenaghan         6        6   52.0       1            282       19
# ..               ...      ...      ...    ...     ...            ...      ...
# 487        SI Kamea         7        7   53.0       3            307        9
# 488      GJ Maxwell        11        9   66.0       2            324        9
# 489        NK Patel        13       13   94.1       1            492        9
# 490        CA Soper         8        8   72.0       3            327        9
# 491      TG Southee         5        5   47.0       4            204        9
#
#     best_bowling_innings  average  economy  strike rate  4wicket_haul  \
# 0                   5/36    20.60     3.99         30.9             1
# 1                   4/20    17.61     3.86         27.3             1
# 2                   3/25    24.28     4.52         32.1             0
# 3                   4/15    23.35     4.98         28.1             1
# 4                   4/43    14.84     5.42         16.4             2
# ..                   ...      ...      ...          ...           ...
# 487                 3/36    34.11     5.79         35.3             0
# 488                 4/52    36.00     4.90         44.0             1
# 489                 2/26    54.66     5.22         62.7             0
# 490                 2/27    36.33     4.54         48.0             0
# 491                 4/22    22.66     4.34         31.3             1
#
#      5wicket_haul  year country
# 0               1  2013     IND
# 1               0  2013      SL
# 2               0  2013     PAK
# 3               0  2013     PAK
# 4               0  2013      NZ
# ..            ...   ...     ...
# 487             0  2022     PNG
# 488             0  2022     AUS
# 489             0  2022     USA
# 490             0  2022     PNG
# 491             0  2022      NZ
#
# [472 rows x 15 columns]

# %%
df_odi["balls_bowled"] = df_odi["overs"].astype(str).str.split(".").apply(lambda x: int(x[0]) * 6 + int(x[1]) if len(x) > 1 else int(x[0]) * 6)
df_odi
# Out:
#               player  matches  innings  overs  maiden  runs conceded  wickets  \
# 0         RA Jadeja        15       15  128.5      15            515       25
# 1      HMRKB Herath        12       12   95.5       4            370       21
# 2       Saeed Ajmal        13       13  112.4       5            510       21
# 3       Junaid Khan        12       12   93.4      10            467       20
# 4    MJ McClenaghan         6        6   52.0       1            282       19
# ..               ...      ...      ...    ...     ...            ...      ...
# 487        SI Kamea         7        7   53.0       3            307        9
# 488      GJ Maxwell        11        9   66.0       2            324        9
# 489        NK Patel        13       13   94.1       1            492        9
# 490        CA Soper         8        8   72.0       3            327        9
# 491      TG Southee         5        5   47.0       4            204        9
#
#     best_bowling_innings  average  economy  strike rate  4wicket_haul  \
# 0                   5/36    20.60     3.99         30.9             1
# 1                   4/20    17.61     3.86         27.3             1
# 2                   3/25    24.28     4.52         32.1             0
# 3                   4/15    23.35     4.98         28.1             1
# 4                   4/43    14.84     5.42         16.4             2
# ..                   ...      ...      ...          ...           ...
# 487                 3/36    34.11     5.79         35.3             0
# 488                 4/52    36.00     4.90         44.0             1
# 489                 2/26    54.66     5.22         62.7             0
# 490                 2/27    36.33     4.54         48.0             0
# 491                 4/22    22.66     4.34         31.3             1
#
#      5wicket_haul  year country  balls_bowled
# 0               1  2013     IND           773
# 1               0  2013      SL           575
# 2               0  2013     PAK           676
# 3               0  2013     PAK           562
# 4               0  2013      NZ           312
# ..            ...   ...     ...           ...
# 487             0  2022     PNG           318
# 488             0  2022     AUS           396
# 489             0  2022     USA           565
# 490             0  2022     PNG           432
# 491             0  2022      NZ           282
#
# [472 rows x 16 columns]

# %%
df_odi=df_odi[['player', 'country', 'matches', 'innings', 'overs','balls_bowled', 'maiden', 'runs conceded', 'wickets',
       'best_bowling_innings', 'average', 'economy', 'strike rate',
       '4wicket_haul', '5wicket_haul', 'year']]

df_odi
# Out:
#               player country  matches  innings  overs  balls_bowled  maiden  \
# 0         RA Jadeja      IND       15       15  128.5           773      15
# 1      HMRKB Herath       SL       12       12   95.5           575       4
# 2       Saeed Ajmal      PAK       13       13  112.4           676       5
# 3       Junaid Khan      PAK       12       12   93.4           562      10
# 4    MJ McClenaghan       NZ        6        6   52.0           312       1
# ..               ...     ...      ...      ...    ...           ...     ...
# 487        SI Kamea      PNG        7        7   53.0           318       3
# 488      GJ Maxwell      AUS       11        9   66.0           396       2
# 489        NK Patel      USA       13       13   94.1           565       1
# 490        CA Soper      PNG        8        8   72.0           432       3
# 491      TG Southee       NZ        5        5   47.0           282       4
#
#      runs conceded  wickets best_bowling_innings  average  economy  \
# 0              515       25                 5/36    20.60     3.99
# 1              370       21                 4/20    17.61     3.86
# 2              510       21                 3/25    24.28     4.52
# 3              467       20                 4/15    23.35     4.98
# 4              282       19                 4/43    14.84     5.42
# ..             ...      ...                  ...      ...      ...
# 487            307        9                 3/36    34.11     5.79
# 488            324        9                 4/52    36.00     4.90
# 489            492        9                 2/26    54.66     5.22
# 490            327        9                 2/27    36.33     4.54
# 491            204        9                 4/22    22.66     4.34
#
#      strike rate  4wicket_haul  5wicket_haul  year
# 0           30.9             1             1  2013
# 1           27.3             1             0  2013
# 2           32.1             0             0  2013
# 3           28.1             1             0  2013
# 4           16.4             2             0  2013
# ..           ...           ...           ...   ...
# 487         35.3             0             0  2022
# 488         44.0             1             0  2022
# 489         62.7             0             0  2022
# 490         48.0             0             0  2022
# 491         31.3             1             0  2022
#
# [472 rows x 16 columns]

# %%
df_odi['weight score']=(0.5*df_odi['wickets'])-(0.3*df_odi['average'])-(0.1*df_odi['economy'])-(0.1*df_odi['strike rate'])
df_odi
# Out:
# C:\Users\vodna\AppData\Local\Temp\ipykernel_20772\4168464295.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_odi['weight score']=(0.5*df_odi['wickets'])-(0.3*df_odi['average'])-(0.1*df_odi['economy'])-(0.1*df_odi['strike rate'])
#               player country  matches  innings  overs  balls_bowled  maiden  \
# 0         RA Jadeja      IND       15       15  128.5           773      15
# 1      HMRKB Herath       SL       12       12   95.5           575       4
# 2       Saeed Ajmal      PAK       13       13  112.4           676       5
# 3       Junaid Khan      PAK       12       12   93.4           562      10
# 4    MJ McClenaghan       NZ        6        6   52.0           312       1
# ..               ...     ...      ...      ...    ...           ...     ...
# 487        SI Kamea      PNG        7        7   53.0           318       3
# 488      GJ Maxwell      AUS       11        9   66.0           396       2
# 489        NK Patel      USA       13       13   94.1           565       1
# 490        CA Soper      PNG        8        8   72.0           432       3
# 491      TG Southee       NZ        5        5   47.0           282       4
#
#      runs conceded  wickets best_bowling_innings  average  economy  \
# 0              515       25                 5/36    20.60     3.99
# 1              370       21                 4/20    17.61     3.86
# 2              510       21                 3/25    24.28     4.52
# 3              467       20                 4/15    23.35     4.98
# 4              282       19                 4/43    14.84     5.42
# ..             ...      ...                  ...      ...      ...
# 487            307        9                 3/36    34.11     5.79
# 488            324        9                 4/52    36.00     4.90
# 489            492        9                 2/26    54.66     5.22
# 490            327        9                 2/27    36.33     4.54
# 491            204        9                 4/22    22.66     4.34
#
#      strike rate  4wicket_haul  5wicket_haul  year  weight score
# 0           30.9             1             1  2013         2.831
# 1           27.3             1             0  2013         2.101
# 2           32.1             0             0  2013        -0.446
# 3           28.1             1             0  2013        -0.313
# 4           16.4             2             0  2013         2.866
# ..           ...           ...           ...   ...           ...
# 487         35.3             0             0  2022        -9.842
# 488         44.0             1             0  2022       -11.190
# 489         62.7             0             0  2022       -18.690
# 490         48.0             0             0  2022       -11.653
# 491         31.3             1             0  2022        -5.862
#
# [472 rows x 17 columns]

# %%
fig,ax=plt.subplots(2,2,figsize=(15, 7))
plt.suptitle("Univariate Analysis of ODI Bowling Performance", fontsize=16)

plt.subplot(2, 2, 1)
sns.histplot(df_odi['average'],bins=10,ax=ax[0,0],kde=True,color='darkblue')
plt.title('Distribution of Bowling Average')
plt.xlabel('Average')
plt.ylabel('Values')

plt.subplot(2, 2, 2)
sns.boxplot(x=df_odi['strike rate'],ax=ax[0,1],color='lightblue')
plt.title('Boxplot of Strike Rate')
plt.xlabel('Strike Rate')

plt.subplot(2, 2, 3)
sns.histplot(df_odi['runs conceded'],bins=10,ax=ax[1,0],kde=True,color='darkgreen')
plt.title('Distribution of Runs Conceded')
plt.xlabel('Runs Conceded')
plt.ylabel('Values')

plt.subplot(2, 2, 4)
sns.boxplot(x=df_odi['economy'],ax=ax[1,1],color='lightblue')
plt.title('Boxplot of Economy Rate')
plt.xlabel('Economy Rate')

plt.tight_layout()
plt.show()

# %%
top_wicket_taker_player=df_odi.groupby('player')[['wickets']].max().reset_index().sort_values(by='wickets',ascending=False).head(10)

plt.figure(figsize=(12,4))

sns.barplot(y=top_wicket_taker_player['player'],x=top_wicket_taker_player['wickets'],color='darkblue')
plt.title("Top 10 wicket takers in ODI")
plt.show()
top_wicket_taker_player
# Out:
#                  player  wickets
# 163  Mustafizur Rahman        30
# 214     SN Netravalkar        28
# 134           MA Starc        27
# 55           CR Woakes        26
# 190          RA Jadeja        25
# 126        LE Plunkett        23
# 92           JC Archer        23
# 73             GT Main        23
# 11           AJ Hosein        22
# 79         Hamza Tahir        22

# %%
top_wicket_by_country=df_odi.groupby('country')[['wickets']].max().reset_index().sort_values(by='wickets',ascending=False).head(10)
plt.figure(figsize=(10,4))

sns.barplot(data=top_wicket_by_country,x='wickets',y='country',color='darkblue')
plt.title('Top 10 wickets by country wise')
plt.show()
top_wicket_by_country
# Out:
#    country  wickets
# 2      BAN       30
# 17     USA       28
# 1      AUS       27
# 3      ENG       26
# 4      IND       25
# 14    SCOT       23
# 18      WI       22
# 15      SL       21
# 9       NZ       21
# 11     PAK       21

# %%
avg_eco_sr_trend=df_odi.groupby('year')[['average','economy','strike rate']].mean().reset_index()

plt.figure(figsize=(10,4))
sns.lineplot(data=avg_eco_sr_trend,x='year',y='average',marker='o',label='average',color='darkblue')
sns.lineplot(data=avg_eco_sr_trend,x='year',y='economy',marker='s',label='economy',color='red')
sns.lineplot(data=avg_eco_sr_trend,x='year',y='strike rate',marker='^',label='strike rate',color='darkgreen')

plt.grid(True)
plt.xlabel('year')
plt.ylabel('values')
plt.title('Yearly Trend of Bowling Average,Economy and Strike Rate')
plt.legend()
plt.show()

avg_eco_sr_trend
# Out:
#    year  average   economy  strike rate
# 0  2013  27.0958  4.745000    34.406000
# 1  2014  25.6306  4.934800    30.906000
# 2  2015  35.0026  5.527000    37.780000
# 3  2016  28.9352  5.036200    33.926000
# 4  2017  32.8738  5.260200    37.270000
# 5  2018  26.0456  4.818800    32.230000
# 6  2019  28.7534  5.232200    32.730000
# 7  2020  42.6200  5.341364    47.163636
# 8  2021  23.7864  4.695000    30.040000
# 9  2022  24.2058  4.690800    31.190000

# %%
best_fig=df_odi.groupby('player')[['best_bowling_innings']].max().reset_index().sort_values(by='best_bowling_innings',ascending=False).head(10)

best_fig
# Out:
#                  player best_bowling_innings
# 88         Imran Tahir                  7/45
# 199        Rashid Khan                  7/18
# 225      Shahid Afridi                  7/12
# 0          A Dananjaya                  6/54
# 105       JR Hazlewood                  6/52
# 1             A Mishra                  6/48
# 107        JW Hastings                  6/45
# 74       Gulbadin Naib                  6/43
# 163  Mustafizur Rahman                  6/43
# 221          STR Binny                   6/4

# %%
top_wicket_year=df_odi.groupby('year')['wickets'].max().reset_index()

plt.figure(figsize=(10,4))
top_player = top_wicket_year.iloc[6]["year"]
colors = ["darkgreen" if player == top_player else "darkblue" for player in top_wicket_year["year"]]
sns.barplot(data=top_wicket_year,x='year',y='wickets',palette=colors)
plt.title('Highest Wickets By Year')
plt.show()

top_wicket_year
# Out:
# C:\Users\vodna\AppData\Local\Temp\ipykernel_20772\696218008.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=top_wicket_year,x='year',y='wickets',palette=colors)
#    year  wickets
# 0  2013       25
# 1  2014       20
# 2  2015       18
# 3  2016       20
# 4  2017       23
# 5  2018       20
# 6  2019       30
# 7  2020       10
# 8  2021       18
# 9  2022       28

# %%
top_maiden=df_odi.groupby('player')['maiden'].max().reset_index().sort_values(by='maiden',ascending=False).head(10)

plt.figure(figsize=(12,4))
sns.barplot(data=top_maiden,x='player',y='maiden',color='darkblue')
plt.title('Top 10 Maiden overs bowled')
plt.show()
top_maiden
# Out:
#             player  maiden
# 112     KAJ Roach       17
# 190     RA Jadeja       15
# 36     BM Scholtz       14
# 105  JR Hazlewood       12
# 29        B Kumar       11
# 108   Junaid Khan       10
# 234      TA Boult       10
# 92      JC Archer       10
# 239    TL Chatara        9
# 150      MRJ Watt        9

# %%
df_odi[['4wicket_haul','5wicket_haul']].sum()

plt.pie(x=[df_odi['4wicket_haul'].sum(),df_odi['5wicket_haul'].sum()],labels=('4 wicket hauls','5 wicket hauls'),colors=['darkblue', 'darkgreen'], autopct='%1.1f%%', explode=(0.1,0), shadow=True)
plt.title('contribution of 4 & 5 wicket hauls in ODI')
# Out:
# Text(0.5, 1.0, 'contribution of 4 & 5 wicket hauls in ODI')

# %%
top_4wickets=df_odi.groupby('player')['4wicket_haul'].max().reset_index().sort_values(by='4wicket_haul',ascending=False).head()

plt.figure(figsize=(8,5))
sns.barplot(data=top_4wickets,x='player',y='4wicket_haul',color='darkblue')
plt.title('Top 5 4wicket hauls')
plt.show()

top_4wickets
# Out:
#               player  4wicket_haul
# 126     LE Plunkett              2
# 143  MJ McClenaghan              2
# 202    S Lamichhane              2
# 179      PJ Cummins              2
# 134        MA Starc              2

# %%
top_5wickets=df_odi.groupby('player')['5wicket_haul'].max().reset_index().sort_values(by='5wicket_haul',ascending=False).head()

plt.figure(figsize=(8,5))
sns.barplot(data=top_5wickets,x='player',y='5wicket_haul',color='darkblue')
plt.title('Top 5 5wicket hauls')
plt.show()

top_5wickets
# Out:
#                  player  5wicket_haul
# 163  Mustafizur Rahman              2
# 134           MA Starc              2
# 122           Karan KC              2
# 0          A Dananjaya              1
# 102          JO Holder              1

# %%
a=df_odi.groupby(['year','player','average','economy', 'strike rate'])['wickets'].max().reset_index()
b=a.loc[a.groupby('year')['wickets'].idxmax()]


fig, ax1 = plt.subplots(figsize=(14, 5))

sns.barplot(x=b['player'], y=b['wickets'], ax=ax1, color='darkblue', label='Wickets',errorbar=None)
ax1.set_ylabel("Wickets")
ax1.set_xlabel("Player")
plt.xticks(rotation=45)


ax2 = ax1.twinx()

sns.lineplot(x=b['player'], y=b['average'], marker='o', ax=ax2, label='Average', color='red',errorbar=None)
sns.lineplot(x=b['player'], y=b['economy'], marker='o', ax=ax2, label='Economy', color='green',errorbar=None)
sns.lineplot(x=b['player'], y=b['strike rate'], marker='o', ax=ax2, label='Strike Rate', color='purple',errorbar=None)

ax2.set_ylabel("Average,Economy and Strike rate", color='black')
ax2.set_xlabel("Player")
plt.xticks(rotation=45)
fig.suptitle("Year wise Top Bowling Performance")

ax1.legend(loc='upper left')
ax2.legend(loc='upper right')


plt.show()

b
# Out:
#      year              player  average  economy  strike rate  wickets
# 34   2013          RA Jadeja     20.60     3.99         30.9       25
# 83   2014          R McLaren     17.90     5.11         21.0       20
# 131  2015  Mustafizur Rahman     12.61     4.25         17.7       18
# 177  2016           MA Starc     19.45     4.47         26.0       20
# 227  2017        LE Plunkett     24.08     5.55         26.0       23
# 253  2018          AU Rashid     23.95     5.56         25.8       20
# 333  2019  Mustafizur Rahman     26.20     6.88         22.8       30
# 350  2020            A Zampa     14.20     4.73         18.0       10
# 408  2021       PVD Chameera     26.66     5.55         28.7       18
# 464  2022     SN Netravalkar     24.14     4.80         30.1       28

# %%
best_10=df_odi.nlargest(10,'weight score')

plt.figure(figsize=(13,5))
sns.barplot(data=best_10,x='weight score',y='player',color='darkblue')
plt.title('Best 10 Players')
plt.show()

best_10
# Out:
#                  player country  matches  innings  overs  balls_bowled  \
# 301           MA Starc      AUS       10       10   92.2           554
# 393       S Lamichhane      NEP        6        5   41.5           251
# 300  Mustafizur Rahman      BAN       13       13  114.1           685
# 443            GT Main     SCOT        9        9   72.1           433
# 6             A Mishra      IND        5        5   47.3           285
# 442     SN Netravalkar      USA       15       15  140.4           844
# 306           N Pokana      PNG        9        9   74.3           447
# 449           TA Boult       NZ        6        6   56.0           336
# 100  Mustafizur Rahman      BAN        6        6   53.2           320
# 4       MJ McClenaghan       NZ        6        6   52.0           312
#
#      maiden  runs conceded  wickets best_bowling_innings  average  economy  \
# 301       5            502       27                 5/26    18.59     5.43
# 393       5            133       18                 6/11     7.38     3.17
# 300       3            786       30                 5/59    26.20     6.88
# 443       6            402       23                 5/52    17.47     5.57
# 6         2            209       18                 6/48    11.61     4.40
# 442       8            676       28                 5/45    24.14     4.80
# 306       7            285       20                 3/25    14.25     3.82
# 449      10            223       18                 4/38    12.38     3.98
# 100       4            227       18                 6/43    12.61     4.25
# 4         1            282       19                 4/43    14.84     5.42
#
#      strike rate  4wicket_haul  5wicket_haul  year  weight score
# 301         20.5             2             2  2019         5.330
# 393         13.9             2             1  2021         5.079
# 300         22.8             1             2  2019         4.172
# 443         18.8             1             1  2022         3.822
# 6           15.8             1             1  2013         3.497
# 442         30.1             0             1  2022         3.268
# 306         22.3             0             0  2019         3.113
# 449         18.6             2             0  2022         3.028
# 100         17.7             0             2  2015         3.022
# 4           16.4             2             0  2013         2.866

# %%
final=best_10[['player','country','weight score']]

# %%
final=final.rename(columns={'country':'Team'})

# %%
final.to_csv('top_5_bow_odi.csv')
