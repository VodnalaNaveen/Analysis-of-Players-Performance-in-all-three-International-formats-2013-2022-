# %%
import pandas as pd

# %%
df = pd.read_csv(r'E:\inno\Cricket EDA\odi_allrounder.csv')
df
# Out:
#      Unnamed: 0            player country  matches  runs highest_score  \
# 0             0        RA Jadeja      IND       15   214           49*
# 1             1         SK Raina      IND       15   237           65*
# 2             2  Mohammad Hafeez      PAK       14   517          136*
# 3             3       SL Malinga       SL       13    26             8
# 4             4   Mohammad Irfan      PAK       13     6            4*
# ..          ...               ...     ...      ...   ...           ...
# 874         874        A Phillip       WI        4    22           21*
# 875         875      TJG Pringle      NED        4     6             6
# 876         876    Rohan Mustafa      UAE        4    67           65*
# 877         877       PM Seelaar      NED        4    60            25
# 878         878   Shoriful Islam      BAN        4     1             1
#
#      batting_avg  100s  wickets best_bowling_innings  bowling_avg  \
# 0          53.50     0       25                 5/36        20.60
# 1          29.62     0        2                  1/2        57.00
# 2          47.00     2        8                 2/34        46.25
# 3           5.20     0       18                 4/34        29.66
# 4           3.00     0       16                 3/32        28.81
# ..           ...   ...      ...                  ...          ...
# 874        22.00     0        4                 2/50        41.00
# 875         1.50     0        1                 1/51       221.00
# 876        22.33     0        5                 2/43        33.20
# 877        15.00     0        2                 2/83       100.00
# 878         1.00     0        6                 4/34        29.50
#
#      5wicket_haul  catches_taken  stumping_made  avg_diff  year  \
# 0               1              4              0     32.90  2013
# 1               0             12              0    -27.37  2013
# 2               0              6              0      0.75  2013
# 3               0              3              0    -24.46  2013
# 4               0              3              0    -25.81  2013
# ..            ...            ...            ...       ...   ...
# 874             0              2              0    -18.99  2022
# 875             0              0              0   -219.49  2022
# 876             0              1              0    -10.86  2022
# 877             0              1              0    -84.99  2022
# 878             0              1              0    -28.49  2022
#
#      allrounder_score
# 0              22.720
# 1              -4.652
# 2               7.325
# 3              -1.418
# 4              -2.643
# ..                ...
# 874            -2.300
# 875           -65.400
# 876             0.472
# 877           -23.400
# 878            -6.650
#
# [879 rows x 17 columns]

# %%
df.isna().sum()
# Out:
# Unnamed: 0              0
# player                  0
# country                 0
# matches                 0
# runs                    0
# highest_score           0
# batting_avg             0
# 100s                    0
# wickets                 0
# best_bowling_innings    0
# bowling_avg             0
# 5wicket_haul            0
# catches_taken           0
# stumping_made           0
# avg_diff                0
# year                    0
# allrounder_score        0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 879 entries, 0 to 878
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            879 non-null    int64
#  1   player                879 non-null    object
#  2   country               879 non-null    object
#  3   matches               879 non-null    int64
#  4   runs                  879 non-null    int64
#  5   highest_score         879 non-null    object
#  6   batting_avg           879 non-null    float64
#  7   100s                  879 non-null    int64
#  8   wickets               879 non-null    int64
#  9   best_bowling_innings  879 non-null    object
#  10  bowling_avg           879 non-null    float64
#  11  5wicket_haul          879 non-null    int64
#  12  catches_taken         879 non-null    int64
#  13  stumping_made         879 non-null    int64
#  14  avg_diff              879 non-null    float64
#  15  year                  879 non-null    int64
#  16  allrounder_score      879 non-null    float64
# dtypes: float64(4), int64(9), object(4)
# memory usage: 116.9+ KB

# %%
df["highest_score"] = df["highest_score"].str.replace("*", "", regex=False).astype(int)

# %%
df = df.drop(columns= 'Unnamed: 0' )

# %%
df = df.rename(columns={'country':'Team'})

# %%
df
# Out:
#                player Team  matches  runs  highest_score  batting_avg  100s  \
# 0          RA Jadeja   IND       15   214             49        53.50     0
# 1           SK Raina   IND       15   237             65        29.62     0
# 2    Mohammad Hafeez   PAK       14   517            136        47.00     2
# 3         SL Malinga    SL       13    26              8         5.20     0
# 4     Mohammad Irfan   PAK       13     6              4         3.00     0
# ..                ...  ...      ...   ...            ...          ...   ...
# 874        A Phillip    WI        4    22             21        22.00     0
# 875      TJG Pringle   NED        4     6              6         1.50     0
# 876    Rohan Mustafa   UAE        4    67             65        22.33     0
# 877       PM Seelaar   NED        4    60             25        15.00     0
# 878   Shoriful Islam   BAN        4     1              1         1.00     0
#
#      wickets best_bowling_innings  bowling_avg  5wicket_haul  catches_taken  \
# 0         25                 5/36        20.60             1              4
# 1          2                  1/2        57.00             0             12
# 2          8                 2/34        46.25             0              6
# 3         18                 4/34        29.66             0              3
# 4         16                 3/32        28.81             0              3
# ..       ...                  ...          ...           ...            ...
# 874        4                 2/50        41.00             0              2
# 875        1                 1/51       221.00             0              0
# 876        5                 2/43        33.20             0              1
# 877        2                 2/83       100.00             0              1
# 878        6                 4/34        29.50             0              1
#
#      stumping_made  avg_diff  year  allrounder_score
# 0                0     32.90  2013            22.720
# 1                0    -27.37  2013            -4.652
# 2                0      0.75  2013             7.325
# 3                0    -24.46  2013            -1.418
# 4                0    -25.81  2013            -2.643
# ..             ...       ...   ...               ...
# 874              0    -18.99  2022            -2.300
# 875              0   -219.49  2022           -65.400
# 876              0    -10.86  2022             0.472
# 877              0    -84.99  2022           -23.400
# 878              0    -28.49  2022            -6.650
#
# [879 rows x 16 columns]

# %%
df['Team'].nunique()
# Out:
# 25

# %%
df['Team'].unique()
# Out:
# array(['IND', 'PAK', 'SL', 'ENG', 'WI', 'ZIM', 'SA', 'AUS', 'IRE', 'SCOT',
#        'NZ', 'NED', 'BAN', 'KENYA', 'CAN', 'AFG', 'UAE', 'HKG', '3 (PAK',
#        'PNG', 'NEP', 'OMA', 'NAM', 'USA', '1 (PAK'], dtype=object)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 6))

# Runs Distribution
plt.subplot(2, 2, 1)
sns.histplot(df["runs"], bins=20, kde=True, color="blue")
plt.title("Distribution of Runs")
plt.xlabel("Runs")
plt.ylabel("Frequency")

# Average Distribution
plt.subplot(2, 2, 2)
sns.histplot(df["batting_avg"], bins=20, kde=True, color="red")
plt.title("Distribution of Batting Average")
plt.xlabel("Average")
plt.ylabel("Frequency")

# Strike Rate Distribution
plt.subplot(2, 2, 3)
sns.histplot(df["bowling_avg"], bins=20, kde=True, color="green")
plt.title("Distribution of bowling average")
plt.xlabel("Strike Rate")
plt.ylabel("Frequency")

# Wickets Distribution
plt.subplot(2, 2, 4)
sns.histplot(df["wickets"], bins=20, kde=True, color="purple")
plt.title("Distribution of Wickets")
plt.xlabel("Wickets")
plt.ylabel("Frequency")

plt.tight_layout()
plt.show()

# %%
top_10_scorers = df.nlargest(10, "runs")[["player", "Team", "runs"]]
top_10_wickets = df.nlargest(10, 'wickets')[['player', 'Team', 'wickets']]

plt.figure(figsize=(5, 3))
sns.barplot(x="runs", y="player", data=top_10_scorers, color= 'darkblue')
plt.xlabel("Total Runs")
plt.ylabel("Player")
plt.title("Top 10 Players by Runs in ODI")
plt.show()

plt.figure(figsize=(5, 3))
sns.barplot(x="wickets", y="player", data=top_10_wickets, color= 'darkblue')
plt.xlabel("Total Runs")
plt.ylabel("Player")
plt.title("Top 10 Players by wickets in ODI")
plt.show()

print(top_10_scorers)
print('----------------------------------------------')
print(top_10_wickets)
# Out:
#                player  Team  runs
# 538          JE Root    ENG   766
# 558  Shakib Al Hasan    BAN   746
# 763       CS MacLeod   SCOT   736
# 207    KS Williamson     NZ   676
# 361          JE Root    ENG   656
# 540        BA Stokes    ENG   594
# 573    KS Williamson     NZ   578
# 776    Sikandar Raza    ZIM   570
# 2    Mohammad Hafeez    PAK   517
# 564         AJ Finch    AUS   507
# ----------------------------------------------
#                  player  Team  wickets
# 546  Mustafizur Rahman    BAN       30
# 767     SN Netravalkar    USA       28
# 571           MA Starc    AUS       27
# 542          CR Woakes    ENG       26
# 0            RA Jadeja    IND       25
# 363        LE Plunkett    ENG       23
# 543          JC Archer    ENG       23
# 789            GT Main   SCOT       23
# 364          AU Rashid    ENG       22
# 765        Hamza Tahir   SCOT       22

# %%
df['Team']= df['Team'].str.replace('1 (','')

# %%
df['Team']= df['Team'].str.replace('3 (','')

# %%
total_runs_by_team = df.groupby('Team')[['runs']].sum().reset_index()
total_runs_by_team
plt.figure(figsize=(7, 5))
sns.barplot(x=total_runs_by_team['runs'], y= total_runs_by_team['Team'], color= 'darkblue')
plt.xlabel("Total Runs")
plt.ylabel("Team")
plt.title("Total runs by Team in ODI")
plt.show()

# %%
yearly_stats = df.groupby(['year'])[['batting_avg', 'bowling_avg']].mean().reset_index()

plt.figure(figsize=(8,3))
sns.lineplot(x="year", y="batting_avg", data=yearly_stats, marker="o", label="Batting Average", color="darkblue")
sns.lineplot(x="year", y="bowling_avg", data=yearly_stats, marker="s", label="Strike Rate", color="darkgreen")

plt.xlabel("Year")
plt.ylabel("Value")
plt.title("Yearly Trend of Batting Average and Strike Rate")
plt.legend()
plt.grid(True)
plt.show()

# %%
top_scorers = df.loc[df.groupby('year')['runs'].idxmax()][['year', 'player', 'runs']]
top_wicket_takers = df.loc[df.groupby('year')['wickets'].idxmax()][['year', 'player', 'wickets']]

fig, ax1 = plt.subplots(figsize=(12, 6))

ax1.set_xlabel("Year (Season)")
ax1.set_ylabel("Top Runs", color="blue")
ax1.plot(top_scorers['year'], top_scorers['runs'], color="blue", marker="o", label="Top Run-Scorer")

for i, txt in enumerate(top_scorers['player']):
    ax1.annotate(txt, 
                 (top_scorers['year'].iloc[i], top_scorers['runs'].iloc[i]), 
                 fontsize=9, color="darkblue", 
                 xytext=(0, 8), textcoords="offset points", ha="center")

ax2 = ax1.twinx()
ax2.set_ylabel("Top Wickets", color="red")
ax2.plot(top_wicket_takers['year'], top_wicket_takers['wickets'], color="red", marker="s", label="Top Wicket-Taker")

for i, txt in enumerate(top_wicket_takers['player']):
    ax2.annotate(txt, 
                 (top_wicket_takers['year'].iloc[i], top_wicket_takers['wickets'].iloc[i]), 
                 fontsize=9, color="red", 
                 xytext=(0, -12), textcoords="offset points", ha="center")

fig.suptitle("Top Run-Scorer & Wicket-Taker Each Year (ODI)")
fig.legend(loc="upper left")

plt.xticks(rotation=45)
plt.grid(True, linestyle="--", alpha=0.5)
plt.tight_layout()
plt.show()

# %%
top_scores_yearly = df.loc[df.groupby("year")["avg_diff"].idxmax(), ["year", "player", "Team", 'runs', 'batting_avg', 'wickets', 'bowling_avg', 'best_bowling_innings', "avg_diff"]]

fig, ax1 = plt.subplots(figsize=(8, 4))
top_player = top_scores_yearly.iloc[3]["year"]
colors = ["darkgreen" if player == top_player else "darkblue" for player in top_scores_yearly["year"]]
sns.barplot(x='player', y="avg_diff", data=top_scores_yearly, palette= colors)
ax1.set_ylabel("avg_difference")
ax1.set_xlabel("Player")
plt.xticks(rotation=45)

ax2 = ax1.twinx()
sns.lineplot(x= top_scores_yearly['player'], y= top_scores_yearly['batting_avg'], marker='s' ,color = 'darkred', label='bating_average', ax=ax2)
sns.lineplot(x= top_scores_yearly['player'], y= top_scores_yearly['bowling_avg'], marker='o' ,color = 'green', label='bowling_average', ax=ax2)
ax2.set_ylabel("Bowling and Batting Average")
ax2.set_xlabel("Player")

plt.title("average difference Per player in ODI")
plt.xticks(rotation=45)
plt.show()

top_scores_yearly
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_22872\469466851.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='player', y="avg_diff", data=top_scores_yearly, palette= colors)
#      year          player  Team  runs  batting_avg  wickets  bowling_avg  \
# 94   2013    MC Sorensen    IRE    55        55.00        5        19.40
# 151  2014      RA Jadeja    IND   108       108.00        7        24.57
# 253  2015      AT Rayudu    IND   209        69.66        1         5.00
# 290  2016      CR Woakes    ENG   129       129.00       14        28.57
# 429  2017  Gulbadin Naib    AFG    92        92.00        3        15.33
# 474  2018      KM Jadhav    IND    70        70.00        6        23.16
# 648  2019      TK Curran    ENG   107       107.00        9        24.88
# 651  2020      C Campher    IRE   127       127.00        5        28.80
# 730  2021       MA Leask   SCOT    51        51.00        5        12.00
# 801  2022        C Green    AUS   170        85.00       11        16.81
#
#     best_bowling_innings  avg_diff
# 94                  3/36     35.60
# 151                 4/28     83.42
# 253                  1/5     64.66
# 290                 4/41    100.42
# 429                 2/15     76.66
# 474                 3/23     46.83
# 648                 4/75     82.11
# 651                 2/50     98.20
# 730                 3/19     39.00
# 801                 5/33     68.18

# %%
top_10_bowlers = df.sort_values(by="best_bowling_innings", ascending=False).head(10)

top_10_bowlers[["player", "best_bowling_innings"]]
# Out:
#                    player best_bowling_innings
# 312          Imran Tahir                  7/45
# 438          Rashid Khan                  7/18
# 36         Shahid Afridi                  7/12
# 400          A Dananjaya                  6/54
# 65              A Mishra                  6/48
# 233    Mustafizur Rahman                  6/43
# 548        Gulbadin Naib                  6/43
# 189            STR Binny                   6/4
# 592  Shaheen Shah Afridi                  6/35
# 472          A Dananjaya                  6/29

# %%
w1 = 0.4 # batting_avg
w2 = 0.3 # bowling_avg
w3 = 0.3 # wickets

# %%
df["weight_Score"] = (w1 * df['batting_avg']) + (w2 * df['bowling_avg']) + (w3 * df['wickets'])
top_players = df.nlargest(10, "weight_Score")[["player", "Team", "weight_Score"]]
top_players
# Out:
#             player Team  weight_Score
# 221   SC Williams   ZIM        95.664
# 178     JF Mooney   IRE        77.400
# 398  PVD Chameera    SL        75.400
# 650     TK Curran   ENG        70.700
# 875   TJG Pringle   NED        67.200
# 76   T Panyangara   ZIM        67.100
# 290     CR Woakes   ENG        64.371
# 856   JDS Neesham    NZ        63.500
# 489     HH Pandya   IND        62.700
# 651     C Campher   IRE        60.940

# %%
top_players.to_csv('top_5_odi_all.csv')
